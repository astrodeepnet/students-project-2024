# %%
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim

# %%
# ---------------------------
# 1) SETUP AND SEED
# ---------------------------
seed_val = 42
np.random.seed(seed_val)
torch.manual_seed(seed_val)

# %%
# ---------------------------
# 2) LOAD ORIGINAL DATA
# ---------------------------
train_df = pd.read_csv('../../../data/train_resample_minmax_all.csv')
test_df = pd.read_csv('../../../data/test_resample_minmax_all.csv')


original_data = pd.concat([train_df, test_df])

# Keep a copy of apogee_id
apogee_ids = original_data["apogee_id"].copy()

# Keep the 17 abundance columns, dropping ID and any extra columns
columns_to_drop = ["apogee_id", "TEFF", "J", "H", "K", "LOGG"]
abundance_data = original_data.drop(columns=columns_to_drop).astype('float32').reset_index(drop=True)

col_names = [
    "C_FE", "CI_FE", "N_FE", "O_FE", "NA_FE", "MG_FE", "AL_FE",
    "SI_FE", "S_FE", "K_FE", "CA_FE", "TI_FE", "V_FE", "CR_FE",
    "MN_FE", "NI_FE", "FE_H"
]

print("Original abundance data shape:", abundance_data.shape)
# Out:
# Original abundance data shape: (161406, 17)

# %%
# ---------------------------
# 3) DEFINE DATASET & MODEL
# ---------------------------
class InverseProjectionDataset(Dataset):
    def __init__(self, x_latent, y_17):
        self.x_latent = torch.tensor(x_latent, dtype=torch.float32)
        self.y_17 = torch.tensor(y_17, dtype=torch.float32)
        self.n = self.x_latent.shape[0]

    def __len__(self):
        return self.n

    def __getitem__(self, idx):
        return self.x_latent[idx], self.y_17[idx]

class InverseProjectionNet(nn.Module):
    """
    A feed-forward network to reconstruct 17D abundances from an N-D embedding.
    Architecture: N -> 64 -> 32 -> 17, with BatchNorm and LeakyReLU.
    """
    def __init__(self, input_dim=2, output_dim=17):
        super().__init__()
        self.fc1 = nn.Linear(input_dim, 64)
        self.bn1 = nn.BatchNorm1d(64)
        self.fc2 = nn.Linear(64, 32)
        self.bn2 = nn.BatchNorm1d(32)
        self.fc3 = nn.Linear(32, output_dim)

    def forward(self, x):
        x = self.fc1(x)
        x = self.bn1(x)
        x = F.leaky_relu(x, negative_slope=0.01)

        x = self.fc2(x)
        x = self.bn2(x)
        x = F.leaky_relu(x, negative_slope=0.01)

        return self.fc3(x)

# %%
# ---------------------------
# Define Global Train/Test Split (consistent across all methods)
# ---------------------------
global_indices = np.arange(len(abundance_data))
np.random.shuffle(global_indices)
split_ratio = 0.9
split_point = int(split_ratio * len(abundance_data))
global_train_idx = set(global_indices[:split_point])
global_test_idx = set(global_indices[split_point:])

print(f"Global train size: {len(global_train_idx)}, Global test size: {len(global_test_idx)}")
# Out:
# Global train size: 145265, Global test size: 16141

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

def train_and_evaluate(latent_df, abundance_df, apogee_ids, method_name, input_dim, global_train_idx, global_test_idx):
    """
    Trains a reconstructor for a given latent_df (with 'apogee_id' + latent dims),
    merging it with the original data to ensure consistent ordering,
    then splits into train/test using the global indices.
    The model is trained on GPU if available.
    """
    # Merge on apogee_id to ensure consistent ordering with the original dataset
    merged = pd.merge(
        latent_df,
        pd.DataFrame({"apogee_id": apogee_ids, "index_orig": np.arange(len(apogee_ids))}),
        on="apogee_id",
        how="inner"
    ).sort_values("index_orig")

    if len(merged) != len(abundance_df):
        print(f"Warning: {method_name} has {len(merged)} rows; original data has {len(abundance_df)}.")

    abundance_ordered = abundance_df.iloc[merged["index_orig"].values]
    latent_cols = [c for c in merged.columns if c not in ["apogee_id", "index_orig"]]
    X_latent = merged[latent_cols].values.astype(np.float32)
    Y_abund = abundance_ordered.values.astype(np.float32)

    mask_train = merged["index_orig"].isin(global_train_idx).values
    mask_test  = merged["index_orig"].isin(global_test_idx).values

    X_train = X_latent[mask_train]
    X_test  = X_latent[mask_test]
    Y_train = Y_abund[mask_train]
    Y_test  = Y_abund[mask_test]

    train_dataset = InverseProjectionDataset(X_train, Y_train)
    test_dataset = InverseProjectionDataset(X_test, Y_test)
    train_loader = DataLoader(train_dataset, batch_size=2048, shuffle=True)
    test_loader  = DataLoader(test_dataset, batch_size=2048, shuffle=False)

    # Build and train the model, and move it to the chosen device.
    model = InverseProjectionNet(input_dim=input_dim, output_dim=17).to(device)
    optimizer = optim.Adam(model.parameters(), lr=1e-4)
    criterion = nn.MSELoss()

    patience = 10
    best_val_loss = float("inf")
    epochs_no_improve = 0
    n_epochs = 100

    train_losses = []
    val_losses = []

    for epoch in range(n_epochs):
        model.train()
        running_loss = 0.0
        for x_batch, y_batch in train_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)

            optimizer.zero_grad()
            preds = model(x_batch)
            loss = criterion(preds, y_batch)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        train_loss = running_loss / len(train_loader)
        train_losses.append(train_loss)

        model.eval()
        running_val_loss = 0.0
        with torch.no_grad():
            for x_batch, y_batch in test_loader:
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)

                preds = model(x_batch)
                loss = criterion(preds, y_batch)
                running_val_loss += loss.item()
        val_loss = running_val_loss / len(test_loader)
        val_losses.append(val_loss)

        if (epoch + 1) % 10 == 0:
            print(f"[{method_name}] Epoch {epoch + 1}/{n_epochs}, Train Loss = {train_loss:.6f}, Val Loss = {val_loss:.6f}")

        if val_loss < best_val_loss - 1e-7:
            best_val_loss = val_loss
            best_model_state = model.state_dict()
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"[{method_name}] Early stopping triggered at epoch {epoch + 1}")
                break

    model.load_state_dict(best_model_state)
    print(f"[{method_name}] Training complete. Best Val Loss: {best_val_loss}")

    model_save_path = f"output_weight/v2_reconstructor_{method_name}.pth"
    torch.save(model.state_dict(), model_save_path)
    print(f"[{method_name}] Model saved to {model_save_path}")

    model.eval()
    all_preds = []
    all_true = []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch = x_batch.to(device)
            preds = model(x_batch)
            all_preds.append(preds.cpu().numpy())
            all_true.append(y_batch.cpu().numpy())
    all_preds = np.concatenate(all_preds, axis=0)
    all_true = np.concatenate(all_true, axis=0)

    mse_global = np.mean((all_preds - all_true)**2)
    cov_matrix = np.cov(all_true, rowvar=False)
    total_variance = np.trace(cov_matrix)
    explained_variance = 1 - (mse_global / total_variance)

    return {
        "model": model,
        "train_loss": train_losses,
        "val_loss": val_losses,
        "X_test": X_test,
        "Y_test": Y_test,
        "all_preds": all_preds,
        "all_true": all_true,
        "mse_global": mse_global,
        "explained_variance": explained_variance,
        "test_idx": merged["index_orig"].values[mask_test],
        "merged_df": merged
    }
# Out:
# Using device: cuda

# %%
projection_files = [
    "autoencoder_latent_space_2D.csv",
    "autoencoder_latent_space_3D.csv",
    "autoencoder_latent_space_4D.csv",
    "CosineKPCA_latent_space_2D.csv",
    "CosineKPCA_latent_space_3D.csv",
    "CosineKPCA_latent_space_4D.csv",
    "PCA_latent_space_2D.csv",
    "PCA_latent_space_3D.csv",
    "PCA_latent_space_4D.csv",
    "siamese_multitask_embedding_2D.csv",
    "siamese_multitask_embedding_3D.csv",
    "siamese_multitask_embedding_4D.csv",
    "siamese_multitask_model_triplet_2D.csv",
    "siamese_multitask_model_triplet_3D.csv",
    "siamese_multitask_model_triplet_4D.csv",
    "tempLoggRegressor_latent_space_2D.csv",
    "tempLoggRegressor_latent_space_3D.csv",
    "tempLoggRegressor_latent_space_4D.csv",
    "tsne_embedding_2D.csv",
    "umap_embedding_2D.csv",
    "umap_embedding_3D.csv",
    "umap_embedding_4D.csv",
    "VAE_latent_space_2D.csv",
    "VAE_latent_space_3D.csv",
    "VAE_latent_space_4D.csv",
]

# Assert that all files are in "output_dataset"
for f in projection_files:
    path = os.path.join("output_dataset", f)
    assert os.path.isfile(path), f"File '{f}' not found in 'output_dataset'!"
print("✅ All projection files are present in 'output_dataset'!")
print(f"Nb projection files: {len(projection_files)}")
# Out:
# ✅ All projection files are present in 'output_dataset'!
# Nb projection files: 25

# %%
# ---------------------------
# 5) LOOP OVER PROJECTION FILES --- SHOULD ONLY BE RUN FOR TRAINING --- if only use comparison can only fun following blocks
# ---------------------------

results = {}

for proj_file in projection_files:
    method_name = os.path.splitext(proj_file)[0]
    method_path = os.path.join("output_dataset", proj_file)
    df_latent = pd.read_csv(method_path)
    if "apogee_id" not in df_latent.columns:
        print(f"Skipping {proj_file}: 'apogee_id' not found.")
        continue

    latent_cols = [c for c in df_latent.columns if c != "apogee_id"]
    input_dim = len(latent_cols)

    print(f"\n=== Training reconstructor for {method_name} (dim={input_dim}) ===")
    out = train_and_evaluate(
        latent_df=df_latent,
        abundance_df=abundance_data,
        apogee_ids=original_data["apogee_id"],
        method_name=method_name,
        input_dim=input_dim,
        global_train_idx=global_train_idx,
        global_test_idx=global_test_idx
    )
    results[method_name] = out
# Out:
# === Training reconstructor for autoencoder_latent_space_2D (dim=2) ===
# [autoencoder_latent_space_2D] Epoch 10/100, Train Loss = 0.021776, Val Loss = 0.018796
# [autoencoder_latent_space_2D] Epoch 20/100, Train Loss = 0.004684, Val Loss = 0.004568
# [autoencoder_latent_space_2D] Epoch 30/100, Train Loss = 0.003113, Val Loss = 0.003027
# [autoencoder_latent_space_2D] Epoch 40/100, Train Loss = 0.002402, Val Loss = 0.002332
# [autoencoder_latent_space_2D] Epoch 50/100, Train Loss = 0.002082, Val Loss = 0.002026
# [autoencoder_latent_space_2D] Epoch 60/100, Train Loss = 0.001867, Val Loss = 0.001810
# [autoencoder_latent_space_2D] Epoch 70/100, Train Loss = 0.001719, Val Loss = 0.001676
# [autoencoder_latent_space_2D] Epoch 80/100, Train Loss = 0.001603, Val Loss = 0.001573
# [autoencoder_latent_space_2D] Epoch 90/100, Train Loss = 0.001537, Val Loss = 0.001496
# [autoencoder_latent_space_2D] Epoch 100/100, Train Loss = 0.001474, Val Loss = 0.001439
# [autoencoder_latent_space_2D] Training complete. Best Val Loss: 0.0014392217999557033
# [autoencoder_latent_space_2D] Model saved to output_weight/v2_reconstructor_autoencoder_latent_space_2D.pth
#
# === Training reconstructor for autoencoder_latent_space_3D (dim=3) ===
# [autoencoder_latent_space_3D] Epoch 10/100, Train Loss = 0.036680, Val Loss = 0.031956
# [autoencoder_latent_space_3D] Epoch 20/100, Train Loss = 0.006357, Val Loss = 0.006125
# [autoencoder_latent_space_3D] Epoch 30/100, Train Loss = 0.004137, Val Loss = 0.004052
# [autoencoder_latent_space_3D] Epoch 40/100, Train Loss = 0.003074, Val Loss = 0.002981
# [autoencoder_latent_space_3D] Epoch 50/100, Train Loss = 0.002346, Val Loss = 0.002268
# [autoencoder_latent_space_3D] Epoch 60/100, Train Loss = 0.001920, Val Loss = 0.001872
# [autoencoder_latent_space_3D] Epoch 70/100, Train Loss = 0.001662, Val Loss = 0.001603
# [autoencoder_latent_space_3D] Epoch 80/100, Train Loss = 0.001492, Val Loss = 0.001445
# [autoencoder_latent_space_3D] Epoch 90/100, Train Loss = 0.001382, Val Loss = 0.001328
# [autoencoder_latent_space_3D] Epoch 100/100, Train Loss = 0.001304, Val Loss = 0.001249
# [autoencoder_latent_space_3D] Training complete. Best Val Loss: 0.0012489211076172069
# [autoencoder_latent_space_3D] Model saved to output_weight/v2_reconstructor_autoencoder_latent_space_3D.pth
#
# === Training reconstructor for autoencoder_latent_space_4D (dim=4) ===
# [autoencoder_latent_space_4D] Epoch 10/100, Train Loss = 0.012943, Val Loss = 0.011642
# [autoencoder_latent_space_4D] Epoch 20/100, Train Loss = 0.004485, Val Loss = 0.004377
# [autoencoder_latent_space_4D] Epoch 30/100, Train Loss = 0.003150, Val Loss = 0.003082
# [autoencoder_latent_space_4D] Epoch 40/100, Train Loss = 0.002405, Val Loss = 0.002378
# [autoencoder_latent_space_4D] Epoch 50/100, Train Loss = 0.001893, Val Loss = 0.001855
# [autoencoder_latent_space_4D] Epoch 60/100, Train Loss = 0.001531, Val Loss = 0.001508
# [autoencoder_latent_space_4D] Epoch 70/100, Train Loss = 0.001311, Val Loss = 0.001292
# [autoencoder_latent_space_4D] Epoch 80/100, Train Loss = 0.001179, Val Loss = 0.001153
# [autoencoder_latent_space_4D] Epoch 90/100, Train Loss = 0.001079, Val Loss = 0.001062
# [autoencoder_latent_space_4D] Epoch 100/100, Train Loss = 0.001023, Val Loss = 0.001000
# [autoencoder_latent_space_4D] Training complete. Best Val Loss: 0.0009998649984481744
# [autoencoder_latent_space_4D] Model saved to output_weight/v2_reconstructor_autoencoder_latent_space_4D.pth
#
# === Training reconstructor for CosineKPCA_latent_space_2D (dim=2) ===
# [CosineKPCA_latent_space_2D] Epoch 10/100, Train Loss = 0.019270, Val Loss = 0.017632
# [CosineKPCA_latent_space_2D] Epoch 20/100, Train Loss = 0.003938, Val Loss = 0.004097
# [CosineKPCA_latent_space_2D] Epoch 30/100, Train Loss = 0.003152, Val Loss = 0.003350
# [CosineKPCA_latent_space_2D] Epoch 40/100, Train Loss = 0.002702, Val Loss = 0.002913
# [CosineKPCA_latent_space_2D] Epoch 50/100, Train Loss = 0.002462, Val Loss = 0.002563
# [CosineKPCA_latent_space_2D] Epoch 60/100, Train Loss = 0.002272, Val Loss = 0.002494
# [CosineKPCA_latent_space_2D] Epoch 70/100, Train Loss = 0.002170, Val Loss = 0.002504
# [CosineKPCA_latent_space_2D] Epoch 80/100, Train Loss = 0.002085, Val Loss = 0.002240
# [CosineKPCA_latent_space_2D] Epoch 90/100, Train Loss = 0.002033, Val Loss = 0.002109
# [CosineKPCA_latent_space_2D] Epoch 100/100, Train Loss = 0.002011, Val Loss = 0.002098
# [CosineKPCA_latent_space_2D] Training complete. Best Val Loss: 0.002049709262792021
# [CosineKPCA_latent_space_2D] Model saved to output_weight/v2_reconstructor_CosineKPCA_latent_space_2D.pth
#
# === Training reconstructor for CosineKPCA_latent_space_3D (dim=3) ===
# [CosineKPCA_latent_space_3D] Epoch 10/100, Train Loss = 0.017368, Val Loss = 0.015832
# [CosineKPCA_latent_space_3D] Epoch 20/100, Train Loss = 0.004039, Val Loss = 0.004017
# [CosineKPCA_latent_space_3D] Epoch 30/100, Train Loss = 0.002870, Val Loss = 0.002841
# [CosineKPCA_latent_space_3D] Epoch 40/100, Train Loss = 0.002396, Val Loss = 0.002395
# [CosineKPCA_latent_space_3D] Epoch 50/100, Train Loss = 0.002101, Val Loss = 0.002101
# [CosineKPCA_latent_space_3D] Epoch 60/100, Train Loss = 0.001895, Val Loss = 0.001916
# [CosineKPCA_latent_space_3D] Epoch 70/100, Train Loss = 0.001775, Val Loss = 0.001836
# [CosineKPCA_latent_space_3D] Epoch 80/100, Train Loss = 0.001695, Val Loss = 0.001717
# [CosineKPCA_latent_space_3D] Epoch 90/100, Train Loss = 0.001637, Val Loss = 0.001653
# [CosineKPCA_latent_space_3D] Epoch 100/100, Train Loss = 0.001603, Val Loss = 0.001608
# [CosineKPCA_latent_space_3D] Training complete. Best Val Loss: 0.0016076831379905343
# [CosineKPCA_latent_space_3D] Model saved to output_weight/v2_reconstructor_CosineKPCA_latent_space_3D.pth
#
# === Training reconstructor for CosineKPCA_latent_space_4D (dim=4) ===
# [CosineKPCA_latent_space_4D] Epoch 10/100, Train Loss = 0.018008, Val Loss = 0.015260
# [CosineKPCA_latent_space_4D] Epoch 20/100, Train Loss = 0.004159, Val Loss = 0.003995
# [CosineKPCA_latent_space_4D] Epoch 30/100, Train Loss = 0.002795, Val Loss = 0.002722
# [CosineKPCA_latent_space_4D] Epoch 40/100, Train Loss = 0.002166, Val Loss = 0.002140
# [CosineKPCA_latent_space_4D] Epoch 50/100, Train Loss = 0.001828, Val Loss = 0.001812
# [CosineKPCA_latent_space_4D] Epoch 60/100, Train Loss = 0.001633, Val Loss = 0.001636
# [CosineKPCA_latent_space_4D] Epoch 70/100, Train Loss = 0.001505, Val Loss = 0.001507
# [CosineKPCA_latent_space_4D] Epoch 80/100, Train Loss = 0.001423, Val Loss = 0.001428
# [CosineKPCA_latent_space_4D] Epoch 90/100, Train Loss = 0.001364, Val Loss = 0.001372
# [CosineKPCA_latent_space_4D] Epoch 100/100, Train Loss = 0.001312, Val Loss = 0.001322
# [CosineKPCA_latent_space_4D] Training complete. Best Val Loss: 0.001322324897046201
# [CosineKPCA_latent_space_4D] Model saved to output_weight/v2_reconstructor_CosineKPCA_latent_space_4D.pth
#
# === Training reconstructor for PCA_latent_space_2D (dim=2) ===
# [PCA_latent_space_2D] Epoch 10/100, Train Loss = 0.030061, Val Loss = 0.025721
# [PCA_latent_space_2D] Epoch 20/100, Train Loss = 0.004603, Val Loss = 0.004501
# [PCA_latent_space_2D] Epoch 30/100, Train Loss = 0.003194, Val Loss = 0.003154
# [PCA_latent_space_2D] Epoch 40/100, Train Loss = 0.002378, Val Loss = 0.002333
# [PCA_latent_space_2D] Epoch 50/100, Train Loss = 0.001938, Val Loss = 0.001945
# [PCA_latent_space_2D] Epoch 60/100, Train Loss = 0.001791, Val Loss = 0.001778
# [PCA_latent_space_2D] Epoch 70/100, Train Loss = 0.001695, Val Loss = 0.001689
# [PCA_latent_space_2D] Epoch 80/100, Train Loss = 0.001646, Val Loss = 0.001643
# [PCA_latent_space_2D] Epoch 90/100, Train Loss = 0.001618, Val Loss = 0.001620
# [PCA_latent_space_2D] Epoch 100/100, Train Loss = 0.001591, Val Loss = 0.001591
# [PCA_latent_space_2D] Training complete. Best Val Loss: 0.0015905945183476433
# [PCA_latent_space_2D] Model saved to output_weight/v2_reconstructor_PCA_latent_space_2D.pth
#
# === Training reconstructor for PCA_latent_space_3D (dim=3) ===
# [PCA_latent_space_3D] Epoch 10/100, Train Loss = 0.014852, Val Loss = 0.013141
# [PCA_latent_space_3D] Epoch 20/100, Train Loss = 0.004109, Val Loss = 0.004015
# [PCA_latent_space_3D] Epoch 30/100, Train Loss = 0.002855, Val Loss = 0.002809
# [PCA_latent_space_3D] Epoch 40/100, Train Loss = 0.002266, Val Loss = 0.002249
# [PCA_latent_space_3D] Epoch 50/100, Train Loss = 0.001881, Val Loss = 0.001867
# [PCA_latent_space_3D] Epoch 60/100, Train Loss = 0.001634, Val Loss = 0.001611
# [PCA_latent_space_3D] Epoch 70/100, Train Loss = 0.001471, Val Loss = 0.001465
# [PCA_latent_space_3D] Epoch 80/100, Train Loss = 0.001372, Val Loss = 0.001365
# [PCA_latent_space_3D] Epoch 90/100, Train Loss = 0.001311, Val Loss = 0.001302
# [PCA_latent_space_3D] Epoch 100/100, Train Loss = 0.001265, Val Loss = 0.001258
# [PCA_latent_space_3D] Training complete. Best Val Loss: 0.0012575208093039691
# [PCA_latent_space_3D] Model saved to output_weight/v2_reconstructor_PCA_latent_space_3D.pth
#
# === Training reconstructor for PCA_latent_space_4D (dim=4) ===
# [PCA_latent_space_4D] Epoch 10/100, Train Loss = 0.018641, Val Loss = 0.015993
# [PCA_latent_space_4D] Epoch 20/100, Train Loss = 0.004308, Val Loss = 0.004163
# [PCA_latent_space_4D] Epoch 30/100, Train Loss = 0.002980, Val Loss = 0.002910
# [PCA_latent_space_4D] Epoch 40/100, Train Loss = 0.002200, Val Loss = 0.002147
# [PCA_latent_space_4D] Epoch 50/100, Train Loss = 0.001699, Val Loss = 0.001658
# [PCA_latent_space_4D] Epoch 60/100, Train Loss = 0.001407, Val Loss = 0.001377
# [PCA_latent_space_4D] Epoch 70/100, Train Loss = 0.001246, Val Loss = 0.001223
# [PCA_latent_space_4D] Epoch 80/100, Train Loss = 0.001138, Val Loss = 0.001132
# [PCA_latent_space_4D] Epoch 90/100, Train Loss = 0.001085, Val Loss = 0.001079
# [PCA_latent_space_4D] Epoch 100/100, Train Loss = 0.001036, Val Loss = 0.001030
# [PCA_latent_space_4D] Training complete. Best Val Loss: 0.0010301061265636235
# [PCA_latent_space_4D] Model saved to output_weight/v2_reconstructor_PCA_latent_space_4D.pth
#
# === Training reconstructor for siamese_multitask_embedding_2D (dim=2) ===
# Warning: siamese_multitask_embedding_2D has 175770 rows; original data has 161406.
# [siamese_multitask_embedding_2D] Epoch 10/100, Train Loss = 0.011692, Val Loss = 0.010352
# [siamese_multitask_embedding_2D] Epoch 20/100, Train Loss = 0.005224, Val Loss = 0.005065
# [siamese_multitask_embedding_2D] Epoch 30/100, Train Loss = 0.004427, Val Loss = 0.004324
# [siamese_multitask_embedding_2D] Epoch 40/100, Train Loss = 0.003907, Val Loss = 0.003847
# [siamese_multitask_embedding_2D] Epoch 50/100, Train Loss = 0.003595, Val Loss = 0.003582
# [siamese_multitask_embedding_2D] Epoch 60/100, Train Loss = 0.003430, Val Loss = 0.003411
# [siamese_multitask_embedding_2D] Epoch 70/100, Train Loss = 0.003336, Val Loss = 0.003336
# [siamese_multitask_embedding_2D] Epoch 80/100, Train Loss = 0.003273, Val Loss = 0.003263
# [siamese_multitask_embedding_2D] Epoch 90/100, Train Loss = 0.003237, Val Loss = 0.003243
# [siamese_multitask_embedding_2D] Epoch 100/100, Train Loss = 0.003205, Val Loss = 0.003229
# [siamese_multitask_embedding_2D] Training complete. Best Val Loss: 0.0031890075446830857
# [siamese_multitask_embedding_2D] Model saved to output_weight/v2_reconstructor_siamese_multitask_embedding_2D.pth
#
# === Training reconstructor for siamese_multitask_embedding_3D (dim=3) ===
# Warning: siamese_multitask_embedding_3D has 175770 rows; original data has 161406.
# [siamese_multitask_embedding_3D] Epoch 10/100, Train Loss = 0.009671, Val Loss = 0.009069
# [siamese_multitask_embedding_3D] Epoch 20/100, Train Loss = 0.005855, Val Loss = 0.005707
# [siamese_multitask_embedding_3D] Epoch 30/100, Train Loss = 0.005082, Val Loss = 0.005020
# [siamese_multitask_embedding_3D] Epoch 40/100, Train Loss = 0.004597, Val Loss = 0.004542
# [siamese_multitask_embedding_3D] Epoch 50/100, Train Loss = 0.004263, Val Loss = 0.004232
# [siamese_multitask_embedding_3D] Epoch 60/100, Train Loss = 0.004043, Val Loss = 0.004017
# [siamese_multitask_embedding_3D] Epoch 70/100, Train Loss = 0.003893, Val Loss = 0.003877
# [siamese_multitask_embedding_3D] Epoch 80/100, Train Loss = 0.003799, Val Loss = 0.003779
# [siamese_multitask_embedding_3D] Epoch 90/100, Train Loss = 0.003723, Val Loss = 0.003707
# [siamese_multitask_embedding_3D] Epoch 100/100, Train Loss = 0.003673, Val Loss = 0.003671
# [siamese_multitask_embedding_3D] Training complete. Best Val Loss: 0.0036695809103548527
# [siamese_multitask_embedding_3D] Model saved to output_weight/v2_reconstructor_siamese_multitask_embedding_3D.pth
#
# === Training reconstructor for siamese_multitask_embedding_4D (dim=4) ===
# [siamese_multitask_embedding_4D] Epoch 10/100, Train Loss = 0.025108, Val Loss = 0.022303
# [siamese_multitask_embedding_4D] Epoch 20/100, Train Loss = 0.005785, Val Loss = 0.005655
# [siamese_multitask_embedding_4D] Epoch 30/100, Train Loss = 0.004018, Val Loss = 0.004002
# [siamese_multitask_embedding_4D] Epoch 40/100, Train Loss = 0.003332, Val Loss = 0.003323
# [siamese_multitask_embedding_4D] Epoch 50/100, Train Loss = 0.002878, Val Loss = 0.002874
# [siamese_multitask_embedding_4D] Epoch 60/100, Train Loss = 0.002553, Val Loss = 0.002551
# [siamese_multitask_embedding_4D] Epoch 70/100, Train Loss = 0.002319, Val Loss = 0.002315
# [siamese_multitask_embedding_4D] Epoch 80/100, Train Loss = 0.002154, Val Loss = 0.002154
# [siamese_multitask_embedding_4D] Epoch 90/100, Train Loss = 0.002039, Val Loss = 0.002038
# [siamese_multitask_embedding_4D] Epoch 100/100, Train Loss = 0.001957, Val Loss = 0.001955
# [siamese_multitask_embedding_4D] Training complete. Best Val Loss: 0.001954974519321695
# [siamese_multitask_embedding_4D] Model saved to output_weight/v2_reconstructor_siamese_multitask_embedding_4D.pth
#
# === Training reconstructor for siamese_multitask_model_triplet_2D (dim=2) ===
# [siamese_multitask_model_triplet_2D] Epoch 10/100, Train Loss = 0.011510, Val Loss = 0.010434
# [siamese_multitask_model_triplet_2D] Epoch 20/100, Train Loss = 0.006539, Val Loss = 0.006411
# [siamese_multitask_model_triplet_2D] Epoch 30/100, Train Loss = 0.005615, Val Loss = 0.005519
# [siamese_multitask_model_triplet_2D] Epoch 40/100, Train Loss = 0.004926, Val Loss = 0.004842
# [siamese_multitask_model_triplet_2D] Epoch 50/100, Train Loss = 0.004451, Val Loss = 0.004391
# [siamese_multitask_model_triplet_2D] Epoch 60/100, Train Loss = 0.004207, Val Loss = 0.004154
# [siamese_multitask_model_triplet_2D] Epoch 70/100, Train Loss = 0.004086, Val Loss = 0.004047
# [siamese_multitask_model_triplet_2D] Epoch 80/100, Train Loss = 0.004001, Val Loss = 0.003977
# [siamese_multitask_model_triplet_2D] Epoch 90/100, Train Loss = 0.003952, Val Loss = 0.003923
# [siamese_multitask_model_triplet_2D] Epoch 100/100, Train Loss = 0.003903, Val Loss = 0.003867
# [siamese_multitask_model_triplet_2D] Training complete. Best Val Loss: 0.0038665834872517735
# [siamese_multitask_model_triplet_2D] Model saved to output_weight/v2_reconstructor_siamese_multitask_model_triplet_2D.pth
#
# === Training reconstructor for siamese_multitask_model_triplet_3D (dim=3) ===
# [siamese_multitask_model_triplet_3D] Epoch 10/100, Train Loss = 0.019268, Val Loss = 0.017054
# [siamese_multitask_model_triplet_3D] Epoch 20/100, Train Loss = 0.007285, Val Loss = 0.007246
# [siamese_multitask_model_triplet_3D] Epoch 30/100, Train Loss = 0.006184, Val Loss = 0.006184
# [siamese_multitask_model_triplet_3D] Epoch 40/100, Train Loss = 0.005529, Val Loss = 0.005527
# [siamese_multitask_model_triplet_3D] Epoch 50/100, Train Loss = 0.005033, Val Loss = 0.005031
# [siamese_multitask_model_triplet_3D] Epoch 60/100, Train Loss = 0.004652, Val Loss = 0.004642
# [siamese_multitask_model_triplet_3D] Epoch 70/100, Train Loss = 0.004391, Val Loss = 0.004392
# [siamese_multitask_model_triplet_3D] Epoch 80/100, Train Loss = 0.004226, Val Loss = 0.004213
# [siamese_multitask_model_triplet_3D] Epoch 90/100, Train Loss = 0.004123, Val Loss = 0.004116
# [siamese_multitask_model_triplet_3D] Epoch 100/100, Train Loss = 0.004056, Val Loss = 0.004046
# [siamese_multitask_model_triplet_3D] Training complete. Best Val Loss: 0.0040459119190927595
# [siamese_multitask_model_triplet_3D] Model saved to output_weight/v2_reconstructor_siamese_multitask_model_triplet_3D.pth
#
# === Training reconstructor for siamese_multitask_model_triplet_4D (dim=4) ===
# [siamese_multitask_model_triplet_4D] Epoch 10/100, Train Loss = 0.012746, Val Loss = 0.011826
# [siamese_multitask_model_triplet_4D] Epoch 20/100, Train Loss = 0.007213, Val Loss = 0.007083
# [siamese_multitask_model_triplet_4D] Epoch 30/100, Train Loss = 0.005983, Val Loss = 0.005919
# [siamese_multitask_model_triplet_4D] Epoch 40/100, Train Loss = 0.005259, Val Loss = 0.005210
# [siamese_multitask_model_triplet_4D] Epoch 50/100, Train Loss = 0.004754, Val Loss = 0.004704
# [siamese_multitask_model_triplet_4D] Epoch 60/100, Train Loss = 0.004380, Val Loss = 0.004337
# [siamese_multitask_model_triplet_4D] Epoch 70/100, Train Loss = 0.004116, Val Loss = 0.004076
# [siamese_multitask_model_triplet_4D] Epoch 80/100, Train Loss = 0.003926, Val Loss = 0.003893
# [siamese_multitask_model_triplet_4D] Epoch 90/100, Train Loss = 0.003803, Val Loss = 0.003773
# [siamese_multitask_model_triplet_4D] Epoch 100/100, Train Loss = 0.003722, Val Loss = 0.003687
# [siamese_multitask_model_triplet_4D] Training complete. Best Val Loss: 0.003686785028548911
# [siamese_multitask_model_triplet_4D] Model saved to output_weight/v2_reconstructor_siamese_multitask_model_triplet_4D.pth
#
# === Training reconstructor for tempLoggRegressor_latent_space_2D (dim=2) ===
# [tempLoggRegressor_latent_space_2D] Epoch 10/100, Train Loss = 0.023608, Val Loss = 0.020966
# [tempLoggRegressor_latent_space_2D] Epoch 20/100, Train Loss = 0.006550, Val Loss = 0.006361
# [tempLoggRegressor_latent_space_2D] Epoch 30/100, Train Loss = 0.004600, Val Loss = 0.004554
# [tempLoggRegressor_latent_space_2D] Epoch 40/100, Train Loss = 0.003916, Val Loss = 0.003927
# [tempLoggRegressor_latent_space_2D] Epoch 50/100, Train Loss = 0.003610, Val Loss = 0.003624
# [tempLoggRegressor_latent_space_2D] Epoch 60/100, Train Loss = 0.003463, Val Loss = 0.003464
# [tempLoggRegressor_latent_space_2D] Epoch 70/100, Train Loss = 0.003351, Val Loss = 0.003376
# [tempLoggRegressor_latent_space_2D] Epoch 80/100, Train Loss = 0.003302, Val Loss = 0.003312
# [tempLoggRegressor_latent_space_2D] Epoch 90/100, Train Loss = 0.003247, Val Loss = 0.003273
# [tempLoggRegressor_latent_space_2D] Epoch 100/100, Train Loss = 0.003219, Val Loss = 0.003246
# [tempLoggRegressor_latent_space_2D] Training complete. Best Val Loss: 0.0032455249747727066
# [tempLoggRegressor_latent_space_2D] Model saved to output_weight/v2_reconstructor_tempLoggRegressor_latent_space_2D.pth
#
# === Training reconstructor for tempLoggRegressor_latent_space_3D (dim=3) ===
# [tempLoggRegressor_latent_space_3D] Epoch 10/100, Train Loss = 0.019747, Val Loss = 0.017311
# [tempLoggRegressor_latent_space_3D] Epoch 20/100, Train Loss = 0.005717, Val Loss = 0.005576
# [tempLoggRegressor_latent_space_3D] Epoch 30/100, Train Loss = 0.004471, Val Loss = 0.004433
# [tempLoggRegressor_latent_space_3D] Epoch 40/100, Train Loss = 0.003819, Val Loss = 0.003781
# [tempLoggRegressor_latent_space_3D] Epoch 50/100, Train Loss = 0.003431, Val Loss = 0.003422
# [tempLoggRegressor_latent_space_3D] Epoch 60/100, Train Loss = 0.003231, Val Loss = 0.003240
# [tempLoggRegressor_latent_space_3D] Epoch 70/100, Train Loss = 0.003126, Val Loss = 0.003136
# [tempLoggRegressor_latent_space_3D] Epoch 80/100, Train Loss = 0.003055, Val Loss = 0.003072
# [tempLoggRegressor_latent_space_3D] Epoch 90/100, Train Loss = 0.003011, Val Loss = 0.003028
# [tempLoggRegressor_latent_space_3D] Epoch 100/100, Train Loss = 0.002976, Val Loss = 0.002999
# [tempLoggRegressor_latent_space_3D] Training complete. Best Val Loss: 0.002999082673341036
# [tempLoggRegressor_latent_space_3D] Model saved to output_weight/v2_reconstructor_tempLoggRegressor_latent_space_3D.pth
#
# === Training reconstructor for tempLoggRegressor_latent_space_4D (dim=4) ===
# [tempLoggRegressor_latent_space_4D] Epoch 10/100, Train Loss = 0.035243, Val Loss = 0.031058
# [tempLoggRegressor_latent_space_4D] Epoch 20/100, Train Loss = 0.007829, Val Loss = 0.007686
# [tempLoggRegressor_latent_space_4D] Epoch 30/100, Train Loss = 0.005433, Val Loss = 0.005421
# [tempLoggRegressor_latent_space_4D] Epoch 40/100, Train Loss = 0.004493, Val Loss = 0.004466
# [tempLoggRegressor_latent_space_4D] Epoch 50/100, Train Loss = 0.003916, Val Loss = 0.003911
# [tempLoggRegressor_latent_space_4D] Epoch 60/100, Train Loss = 0.003546, Val Loss = 0.003553
# [tempLoggRegressor_latent_space_4D] Epoch 70/100, Train Loss = 0.003335, Val Loss = 0.003345
# [tempLoggRegressor_latent_space_4D] Epoch 80/100, Train Loss = 0.003194, Val Loss = 0.003199
# [tempLoggRegressor_latent_space_4D] Epoch 90/100, Train Loss = 0.003095, Val Loss = 0.003101
# [tempLoggRegressor_latent_space_4D] Epoch 100/100, Train Loss = 0.003005, Val Loss = 0.003021
# [tempLoggRegressor_latent_space_4D] Training complete. Best Val Loss: 0.0030211068806238472
# [tempLoggRegressor_latent_space_4D] Model saved to output_weight/v2_reconstructor_tempLoggRegressor_latent_space_4D.pth
#
# === Training reconstructor for tsne_embedding_2D (dim=2) ===
# [tsne_embedding_2D] Epoch 10/100, Train Loss = 0.014263, Val Loss = 0.012537
# [tsne_embedding_2D] Epoch 20/100, Train Loss = 0.004224, Val Loss = 0.004144
# [tsne_embedding_2D] Epoch 30/100, Train Loss = 0.003293, Val Loss = 0.003254
# [tsne_embedding_2D] Epoch 40/100, Train Loss = 0.002746, Val Loss = 0.002720
# [tsne_embedding_2D] Epoch 50/100, Train Loss = 0.002320, Val Loss = 0.002297
# [tsne_embedding_2D] Epoch 60/100, Train Loss = 0.002061, Val Loss = 0.002056
# [tsne_embedding_2D] Epoch 70/100, Train Loss = 0.001915, Val Loss = 0.001896
# [tsne_embedding_2D] Epoch 80/100, Train Loss = 0.001828, Val Loss = 0.001799
# [tsne_embedding_2D] Epoch 90/100, Train Loss = 0.001753, Val Loss = 0.001727
# [tsne_embedding_2D] Epoch 100/100, Train Loss = 0.001696, Val Loss = 0.001676
# [tsne_embedding_2D] Training complete. Best Val Loss: 0.0016760559956310317
# [tsne_embedding_2D] Model saved to output_weight/v2_reconstructor_tsne_embedding_2D.pth
#
# === Training reconstructor for umap_embedding_2D (dim=2) ===
# [umap_embedding_2D] Epoch 10/100, Train Loss = 0.013081, Val Loss = 0.011374
# [umap_embedding_2D] Epoch 20/100, Train Loss = 0.003232, Val Loss = 0.003151
# [umap_embedding_2D] Epoch 30/100, Train Loss = 0.002419, Val Loss = 0.002388
# [umap_embedding_2D] Epoch 40/100, Train Loss = 0.002071, Val Loss = 0.002042
# [umap_embedding_2D] Epoch 50/100, Train Loss = 0.001870, Val Loss = 0.001840
# [umap_embedding_2D] Epoch 60/100, Train Loss = 0.001742, Val Loss = 0.001722
# [umap_embedding_2D] Epoch 70/100, Train Loss = 0.001653, Val Loss = 0.001642
# [umap_embedding_2D] Epoch 80/100, Train Loss = 0.001573, Val Loss = 0.001549
# [umap_embedding_2D] Epoch 90/100, Train Loss = 0.001525, Val Loss = 0.001500
# [umap_embedding_2D] Epoch 100/100, Train Loss = 0.001492, Val Loss = 0.001485
# [umap_embedding_2D] Training complete. Best Val Loss: 0.001468480986659415
# [umap_embedding_2D] Model saved to output_weight/v2_reconstructor_umap_embedding_2D.pth
#
# === Training reconstructor for umap_embedding_3D (dim=3) ===
# [umap_embedding_3D] Epoch 10/100, Train Loss = 0.024505, Val Loss = 0.021054
# [umap_embedding_3D] Epoch 20/100, Train Loss = 0.003369, Val Loss = 0.003204
# [umap_embedding_3D] Epoch 30/100, Train Loss = 0.002331, Val Loss = 0.002288
# [umap_embedding_3D] Epoch 40/100, Train Loss = 0.001988, Val Loss = 0.001940
# [umap_embedding_3D] Epoch 50/100, Train Loss = 0.001787, Val Loss = 0.001752
# [umap_embedding_3D] Epoch 60/100, Train Loss = 0.001651, Val Loss = 0.001630
# [umap_embedding_3D] Epoch 70/100, Train Loss = 0.001560, Val Loss = 0.001529
# [umap_embedding_3D] Epoch 80/100, Train Loss = 0.001484, Val Loss = 0.001452
# [umap_embedding_3D] Epoch 90/100, Train Loss = 0.001436, Val Loss = 0.001410
# [umap_embedding_3D] Epoch 100/100, Train Loss = 0.001383, Val Loss = 0.001357
# [umap_embedding_3D] Training complete. Best Val Loss: 0.0013574629701906815
# [umap_embedding_3D] Model saved to output_weight/v2_reconstructor_umap_embedding_3D.pth
#
# === Training reconstructor for umap_embedding_4D (dim=4) ===
# [umap_embedding_4D] Epoch 10/100, Train Loss = 0.011460, Val Loss = 0.009667
# [umap_embedding_4D] Epoch 20/100, Train Loss = 0.002670, Val Loss = 0.002556
# [umap_embedding_4D] Epoch 30/100, Train Loss = 0.002063, Val Loss = 0.001999
# [umap_embedding_4D] Epoch 40/100, Train Loss = 0.001784, Val Loss = 0.001736
# [umap_embedding_4D] Epoch 50/100, Train Loss = 0.001602, Val Loss = 0.001558
# [umap_embedding_4D] Epoch 60/100, Train Loss = 0.001510, Val Loss = 0.001477
# [umap_embedding_4D] Epoch 70/100, Train Loss = 0.001427, Val Loss = 0.001397
# [umap_embedding_4D] Epoch 80/100, Train Loss = 0.001365, Val Loss = 0.001335
# [umap_embedding_4D] Epoch 90/100, Train Loss = 0.001325, Val Loss = 0.001293
# [umap_embedding_4D] Epoch 100/100, Train Loss = 0.001284, Val Loss = 0.001253
# [umap_embedding_4D] Training complete. Best Val Loss: 0.001253237685887143
# [umap_embedding_4D] Model saved to output_weight/v2_reconstructor_umap_embedding_4D.pth
#
# === Training reconstructor for VAE_latent_space_2D (dim=2) ===
# [VAE_latent_space_2D] Epoch 10/100, Train Loss = 0.013266, Val Loss = 0.011657
# [VAE_latent_space_2D] Epoch 20/100, Train Loss = 0.004215, Val Loss = 0.004123
# [VAE_latent_space_2D] Epoch 30/100, Train Loss = 0.003104, Val Loss = 0.003044
# [VAE_latent_space_2D] Epoch 40/100, Train Loss = 0.002381, Val Loss = 0.002351
# [VAE_latent_space_2D] Epoch 50/100, Train Loss = 0.001981, Val Loss = 0.001967
# [VAE_latent_space_2D] Epoch 60/100, Train Loss = 0.001762, Val Loss = 0.001751
# [VAE_latent_space_2D] Epoch 70/100, Train Loss = 0.001620, Val Loss = 0.001607
# [VAE_latent_space_2D] Epoch 80/100, Train Loss = 0.001545, Val Loss = 0.001524
# [VAE_latent_space_2D] Epoch 90/100, Train Loss = 0.001470, Val Loss = 0.001464
# [VAE_latent_space_2D] Epoch 100/100, Train Loss = 0.001416, Val Loss = 0.001406
# [VAE_latent_space_2D] Training complete. Best Val Loss: 0.0014062704722164199
# [VAE_latent_space_2D] Model saved to output_weight/v2_reconstructor_VAE_latent_space_2D.pth
#
# === Training reconstructor for VAE_latent_space_3D (dim=3) ===
# [VAE_latent_space_3D] Epoch 10/100, Train Loss = 0.020595, Val Loss = 0.018175
# [VAE_latent_space_3D] Epoch 20/100, Train Loss = 0.004447, Val Loss = 0.004411
# [VAE_latent_space_3D] Epoch 30/100, Train Loss = 0.003209, Val Loss = 0.003203
# [VAE_latent_space_3D] Epoch 40/100, Train Loss = 0.002531, Val Loss = 0.002518
# [VAE_latent_space_3D] Epoch 50/100, Train Loss = 0.002049, Val Loss = 0.002025
# [VAE_latent_space_3D] Epoch 60/100, Train Loss = 0.001729, Val Loss = 0.001706
# [VAE_latent_space_3D] Epoch 70/100, Train Loss = 0.001540, Val Loss = 0.001519
# [VAE_latent_space_3D] Epoch 80/100, Train Loss = 0.001411, Val Loss = 0.001394
# [VAE_latent_space_3D] Epoch 90/100, Train Loss = 0.001316, Val Loss = 0.001304
# [VAE_latent_space_3D] Epoch 100/100, Train Loss = 0.001258, Val Loss = 0.001240
# [VAE_latent_space_3D] Training complete. Best Val Loss: 0.0012401896819937974
# [VAE_latent_space_3D] Model saved to output_weight/v2_reconstructor_VAE_latent_space_3D.pth
#
# === Training reconstructor for VAE_latent_space_4D (dim=4) ===
# [VAE_latent_space_4D] Epoch 10/100, Train Loss = 0.022707, Val Loss = 0.019834
# [VAE_latent_space_4D] Epoch 20/100, Train Loss = 0.005526, Val Loss = 0.005452
# [VAE_latent_space_4D] Epoch 30/100, Train Loss = 0.003823, Val Loss = 0.003809
# [VAE_latent_space_4D] Epoch 40/100, Train Loss = 0.002902, Val Loss = 0.002896
# [VAE_latent_space_4D] Epoch 50/100, Train Loss = 0.002277, Val Loss = 0.002274
# [VAE_latent_space_4D] Epoch 60/100, Train Loss = 0.001864, Val Loss = 0.001860
# [VAE_latent_space_4D] Epoch 70/100, Train Loss = 0.001587, Val Loss = 0.001585
# [VAE_latent_space_4D] Epoch 80/100, Train Loss = 0.001404, Val Loss = 0.001401
# [VAE_latent_space_4D] Epoch 90/100, Train Loss = 0.001276, Val Loss = 0.001275
# [VAE_latent_space_4D] Epoch 100/100, Train Loss = 0.001183, Val Loss = 0.001188
# [VAE_latent_space_4D] Training complete. Best Val Loss: 0.0011877768411068246
# [VAE_latent_space_4D] Model saved to output_weight/v2_reconstructor_VAE_latent_space_4D.pth

# %%
class InverseProjectionInferenceDataset(Dataset):
    """
    Redifinition used for re construction.
    """
    def __init__(self, x_latent):
        self.x_latent = torch.tensor(x_latent, dtype=torch.float32)
        self.n = self.x_latent.shape[0]

    def __len__(self):
        return self.n

    def __getitem__(self, idx):
        return self.x_latent[idx]

# %%
os.makedirs("reconstructed_csv", exist_ok=True)

for proj_file in projection_files:
    method_name = os.path.splitext(proj_file)[0]
    latent_path = os.path.join("output_dataset", proj_file)
    weights_path = os.path.join("output_weight", f"v2_reconstructor_{method_name}.pth")


    if not os.path.isfile(latent_path):
        print(f"[{method_name}] Fichier latent introuvable: {latent_path}. Skip.")
        continue
    if not os.path.isfile(weights_path):
        print(f"[{method_name}] Fichier de poids introuvable: {weights_path}. Skip.")
        continue

    print(f"\n=== Reconstruction du test set pour {method_name} ===")

    df_latent = pd.read_csv(latent_path)
    if "apogee_id" not in df_latent.columns:
        print(f"Skipping {proj_file}: 'apogee_id' not found.")
        continue

    temp_index_df = pd.DataFrame({"apogee_id": apogee_ids, "index_orig": np.arange(len(apogee_ids))})
    merged = pd.merge(
        df_latent,
        temp_index_df,
        on="apogee_id",
        how="inner"
    ).sort_values("index_orig")

    mask_test = merged["index_orig"].isin(global_test_idx).values
    merged_test = merged.loc[mask_test].copy()
    merged_test_sorted = merged_test.sort_values("index_orig")  # pour ordre croissant
    latent_cols = [c for c in merged_test_sorted.columns if c not in ["apogee_id", "index_orig"]]

    X_test = merged_test_sorted[latent_cols].values.astype(np.float32)

    input_dim = len(latent_cols)
    model = InverseProjectionNet(input_dim=input_dim, output_dim=17).to(device)
    model.load_state_dict(torch.load(weights_path, map_location=device))
    model.eval()

    test_dataset = InverseProjectionInferenceDataset(X_test)
    test_loader  = DataLoader(test_dataset, batch_size=2048, shuffle=False)

    all_preds = []
    with torch.no_grad():
        for batch_x in test_loader:
            batch_x = batch_x.to(device)
            preds = model(batch_x)
            all_preds.append(preds.cpu().numpy())

    all_preds = np.concatenate(all_preds, axis=0)


    recon_df = pd.DataFrame(all_preds, columns=col_names)
    recon_df.insert(0, "apogee_id", merged_test_sorted["apogee_id"].values)
    recon_df.insert(1, "index_orig", merged_test_sorted["index_orig"].values)

    output_csv_path = os.path.join("reconstructed_csv", f"v2_test_reconstructed_{method_name}.csv")
    recon_df.to_csv(output_csv_path, index=False)
    print(f"[{method_name}] Données reconstruites du test set sauvegardées dans: {output_csv_path}")

print("\nTerminé ! Vous avez maintenant un 'test_original.csv' et, pour chaque méthode, un 'test_reconstructed_<method>.csv' dans le dossier 'reconstructed_csv'.")
# Out:
# === Reconstruction du test set pour autoencoder_latent_space_2D ===
# [autoencoder_latent_space_2D] Données reconstruites du test set sauvegardées dans: reconstructed_csv/v2_test_reconstructed_autoencoder_latent_space_2D.csv
#
# === Reconstruction du test set pour autoencoder_latent_space_3D ===
# [autoencoder_latent_space_3D] Données reconstruites du test set sauvegardées dans: reconstructed_csv/v2_test_reconstructed_autoencoder_latent_space_3D.csv
#
# === Reconstruction du test set pour autoencoder_latent_space_4D ===
# [autoencoder_latent_space_4D] Données reconstruites du test set sauvegardées dans: reconstructed_csv/v2_test_reconstructed_autoencoder_latent_space_4D.csv
#
# === Reconstruction du test set pour CosineKPCA_latent_space_2D ===
# [CosineKPCA_latent_space_2D] Données reconstruites du test set sauvegardées dans: reconstructed_csv/v2_test_reconstructed_CosineKPCA_latent_space_2D.csv
#
# === Reconstruction du test set pour CosineKPCA_latent_space_3D ===
# [CosineKPCA_latent_space_3D] Données reconstruites du test set sauvegardées dans: reconstructed_csv/v2_test_reconstructed_CosineKPCA_latent_space_3D.csv
#
# === Reconstruction du test set pour CosineKPCA_latent_space_4D ===
# [CosineKPCA_latent_space_4D] Données reconstruites du test set sauvegardées dans: reconstructed_csv/v2_test_reconstructed_CosineKPCA_latent_space_4D.csv
#
# === Reconstruction du test set pour PCA_latent_space_2D ===
# [PCA_latent_space_2D] Données reconstruites du test set sauvegardées dans: reconstructed_csv/v2_test_reconstructed_PCA_latent_space_2D.csv
#
# === Reconstruction du test set pour PCA_latent_space_3D ===
# [PCA_latent_space_3D] Données reconstruites du test set sauvegardées dans: reconstructed_csv/v2_test_reconstructed_PCA_latent_space_3D.csv
#
# === Reconstruction du test set pour PCA_latent_space_4D ===
# [PCA_latent_space_4D] Données reconstruites du test set sauvegardées dans: reconstructed_csv/v2_test_reconstructed_PCA_latent_space_4D.csv
#
# === Reconstruction du test set pour siamese_multitask_embedding_2D ===
# [siamese_multitask_embedding_2D] Données reconstruites du test set sauvegardées dans: reconstructed_csv/v2_test_reconstructed_siamese_multitask_embedding_2D.csv
#
# === Reconstruction du test set pour siamese_multitask_embedding_3D ===
# [siamese_multitask_embedding_3D] Données reconstruites du test set sauvegardées dans: reconstructed_csv/v2_test_reconstructed_siamese_multitask_embedding_3D.csv
#
# === Reconstruction du test set pour siamese_multitask_embedding_4D ===
# [siamese_multitask_embedding_4D] Données reconstruites du test set sauvegardées dans: reconstructed_csv/v2_test_reconstructed_siamese_multitask_embedding_4D.csv
#
# === Reconstruction du test set pour siamese_multitask_model_triplet_2D ===
# [siamese_multitask_model_triplet_2D] Données reconstruites du test set sauvegardées dans: reconstructed_csv/v2_test_reconstructed_siamese_multitask_model_triplet_2D.csv
#
# === Reconstruction du test set pour siamese_multitask_model_triplet_3D ===
# [siamese_multitask_model_triplet_3D] Données reconstruites du test set sauvegardées dans: reconstructed_csv/v2_test_reconstructed_siamese_multitask_model_triplet_3D.csv
#
# === Reconstruction du test set pour siamese_multitask_model_triplet_4D ===
# [siamese_multitask_model_triplet_4D] Données reconstruites du test set sauvegardées dans: reconstructed_csv/v2_test_reconstructed_siamese_multitask_model_triplet_4D.csv
#
# === Reconstruction du test set pour tempLoggRegressor_latent_space_2D ===
# [tempLoggRegressor_latent_space_2D] Données reconstruites du test set sauvegardées dans: reconstructed_csv/v2_test_reconstructed_tempLoggRegressor_latent_space_2D.csv
#
# === Reconstruction du test set pour tempLoggRegressor_latent_space_3D ===
# [tempLoggRegressor_latent_space_3D] Données reconstruites du test set sauvegardées dans: reconstructed_csv/v2_test_reconstructed_tempLoggRegressor_latent_space_3D.csv
#
# === Reconstruction du test set pour tempLoggRegressor_latent_space_4D ===
# [tempLoggRegressor_latent_space_4D] Données reconstruites du test set sauvegardées dans: reconstructed_csv/v2_test_reconstructed_tempLoggRegressor_latent_space_4D.csv
#
# === Reconstruction du test set pour tsne_embedding_2D ===
# [tsne_embedding_2D] Données reconstruites du test set sauvegardées dans: reconstructed_csv/v2_test_reconstructed_tsne_embedding_2D.csv
#
# === Reconstruction du test set pour umap_embedding_2D ===
# [umap_embedding_2D] Données reconstruites du test set sauvegardées dans: reconstructed_csv/v2_test_reconstructed_umap_embedding_2D.csv
#
# === Reconstruction du test set pour umap_embedding_3D ===
# [umap_embedding_3D] Données reconstruites du test set sauvegardées dans: reconstructed_csv/v2_test_reconstructed_umap_embedding_3D.csv
#
# === Reconstruction du test set pour umap_embedding_4D ===
# [umap_embedding_4D] Données reconstruites du test set sauvegardées dans: reconstructed_csv/v2_test_reconstructed_umap_embedding_4D.csv
#
# === Reconstruction du test set pour VAE_latent_space_2D ===
# [VAE_latent_space_2D] Données reconstruites du test set sauvegardées dans: reconstructed_csv/v2_test_reconstructed_VAE_latent_space_2D.csv
#
# === Reconstruction du test set pour VAE_latent_space_3D ===
# [VAE_latent_space_3D] Données reconstruites du test set sauvegardées dans: reconstructed_csv/v2_test_reconstructed_VAE_latent_space_3D.csv
#
# === Reconstruction du test set pour VAE_latent_space_4D ===
# [VAE_latent_space_4D] Données reconstruites du test set sauvegardées dans: reconstructed_csv/v2_test_reconstructed_VAE_latent_space_4D.csv
#
# Terminé ! Vous avez maintenant un 'test_original.csv' et, pour chaque méthode, un 'test_reconstructed_<method>.csv' dans le dossier 'reconstructed_csv'.

# %%
import numpy as np
import matplotlib.pyplot as plt

# ---------------------------
# 7) PICK THE SAME STAR FROM THE TEST SET (CONSISTENT SPLIT) AND PLOT ALL METHODS
# ---------------------------
# 1) Select the first method's test set to guarantee the star is in the test set of at least one method
method_names = list(results.keys())
first_method = method_names[0]

first_method_test_idx = results[first_method]["test_idx"]
row_index_orig = first_method_test_idx[0]  # e.g. pick the first test sample
chosen_id = original_data["apogee_id"].iloc[row_index_orig]
print(f"\nComparing reconstructions for apogee_id={chosen_id} (row_index_orig={row_index_orig})")

# 2) Get the original abundance for this star
original_abundance = abundance_data.iloc[row_index_orig].values

# 3) Prepare a grid of subplots, one per method
n_methods = len(method_names)
ncols = 3  # e.g. 3 columns
nrows = (n_methods + ncols - 1) // ncols  # enough rows to fit all methods
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(18, 5*nrows))
axes = axes.flatten()

# (Optional) labels for subplots: (a), (b), (c), ...
letters = "abcdefghijklmnopqrstuvwxyz"

# 4) For each method, plot "Original vs. Reconstruction" in its own subplot
for idx, m_name in enumerate(method_names):
    ax = axes[idx]

    # Retrieve the merged_df to find index_orig
    merged_df = results[m_name]["merged_df"]
    match = merged_df[merged_df["apogee_id"] == "2M16422378-1901581"]
    if match.empty:
        # Star not found in this method's dataset (e.g. if some rows got dropped)
        ax.text(0.5, 0.5, f"{m_name}\nNot found", ha='center', va='center', transform=ax.transAxes)
        ax.axis("off")
        continue

    # Check if the star is in the test set for this method
    test_idx_for_method = results[m_name]["test_idx"]
    idx_pos = np.where(test_idx_for_method == row_index_orig)[0]
    if len(idx_pos) == 0:
        # The star ended up in the train set for this method
        ax.text(0.5, 0.5, f"{m_name}\nIn train set", ha='center', va='center', transform=ax.transAxes)
        ax.axis("off")
        continue

    # Retrieve the reconstruction from all_preds
    pos_in_test = idx_pos[0]
    recon = results[m_name]["all_preds"][pos_in_test]

    # Plot the original abundance (blue line) vs. reconstruction (orange line)
    ax.plot(range(len(col_names)), original_abundance, marker='o', label="Original")
    ax.plot(range(len(col_names)), recon, marker='x', label="Reconstructed")

    # Cosmetic adjustments
    ax.set_xticks(range(len(col_names)))
    ax.set_xticklabels(col_names, rotation=45)
    subplot_label = f"({letters[idx]})" if idx < len(letters) else ""
    ax.set_title(f"{subplot_label} {m_name}", fontsize=10)
    ax.legend(fontsize=8)

# Hide any extra subplots if we have more subplot slots than methods
for j in range(idx+1, len(axes)):
    axes[j].axis("off")

plt.tight_layout()
plt.show()
# Out:
# Comparing reconstructions for apogee_id=2M06164840-7416584 (row_index_orig=5)

# %%
import numpy as np
import torch
from torch.utils.data import DataLoader

def compute_train_mse_for_method(m_name, results_dict, abundance_df, global_train_idx):
    """
    Rebuild the train dataset for method m_name, run inference,
    and compute the MSE on the training set.
    """
    # 1) Extract the model
    model = results_dict[m_name]["model"]
    model.eval()  # inference mode

    # 2) Extract the merged_df to see how latent data lines up with original indices
    merged_df = results_dict[m_name]["merged_df"]

    # 3) Determine which rows are in the train set for this method
    mask_train = merged_df["index_orig"].isin(global_train_idx).values

    # 4) Extract the latent columns
    latent_cols = [c for c in merged_df.columns if c not in ["apogee_id", "index_orig"]]
    X_latent = merged_df[latent_cols].values.astype(np.float32)

    # 5) Align abundance data in the same order, then slice for train
    Y_abund = abundance_df.iloc[merged_df["index_orig"].values].values.astype(np.float32)

    X_train = X_latent[mask_train]
    Y_train = Y_abund[mask_train]

    # 6) Create the train dataset and loader
    train_dataset = InverseProjectionDataset(X_train, Y_train)
    train_loader = DataLoader(train_dataset, batch_size=2048, shuffle=False)

    # 7) Run inference on the train set
    all_preds = []
    all_true = []
    with torch.no_grad():
        for x_batch, y_batch in train_loader:
            x_batch = x_batch.to(device)
            preds = model(x_batch)
            all_preds.append(preds.cpu().numpy())
            all_true.append(y_batch.numpy())
    all_preds = np.concatenate(all_preds, axis=0)
    all_true = np.concatenate(all_true, axis=0)

    # 8) Compute the MSE
    mse_train = np.mean((all_preds - all_true)**2)
    return mse_train

# loop over each method and compute train MSE

for m_name in results.keys():
    mse_train = compute_train_mse_for_method(m_name, results, abundance_data, global_train_idx)
    print(f"{m_name} - Train MSE: {mse_train:.6f}")
# Out:
# autoencoder_latent_space_2D - Train MSE: 0.001416
# autoencoder_latent_space_3D - Train MSE: 0.001233
# autoencoder_latent_space_4D - Train MSE: 0.000983
# CosineKPCA_latent_space_2D - Train MSE: 0.002059
# CosineKPCA_latent_space_3D - Train MSE: 0.001574
# CosineKPCA_latent_space_4D - Train MSE: 0.001286
# PCA_latent_space_2D - Train MSE: 0.001556
# PCA_latent_space_3D - Train MSE: 0.001231
# PCA_latent_space_4D - Train MSE: 0.001007
# siamese_multitask_embedding_2D - Train MSE: 0.003221
# siamese_multitask_embedding_3D - Train MSE: 0.003658
# siamese_multitask_embedding_4D - Train MSE: 0.001932
# siamese_multitask_model_triplet_2D - Train MSE: 0.003881
# siamese_multitask_model_triplet_3D - Train MSE: 0.004032
# siamese_multitask_model_triplet_4D - Train MSE: 0.003699
# tempLoggRegressor_latent_space_2D - Train MSE: 0.003186
# tempLoggRegressor_latent_space_3D - Train MSE: 0.002949
# tempLoggRegressor_latent_space_4D - Train MSE: 0.002969
# tsne_embedding_2D - Train MSE: 0.001659
# umap_embedding_2D - Train MSE: 0.001461
# umap_embedding_3D - Train MSE: 0.001331
# umap_embedding_4D - Train MSE: 0.001229
# VAE_latent_space_2D - Train MSE: 0.001386
# VAE_latent_space_3D - Train MSE: 0.001224
# VAE_latent_space_4D - Train MSE: 0.001157

# %%
import numpy as np
import matplotlib.pyplot as plt

# Dictionary to store per-star errors (distances) for each method
method_starwise_distances = {}

for m_name, data_dict in results.items():
    all_preds = data_dict["all_preds"]  # shape [N_test, 17]
    all_true = data_dict["all_true"]    # shape [N_test, 17]

    # Compute the L2 distance for each star: sqrt( sum( (pred - true)^2 ) )
    #starwise_dist = np.sqrt(np.sum((all_preds - all_true)**2, axis=1))  # shape [N_test]
    starwise_dist = np.mean(np.abs(all_preds - all_true), axis=1)


    method_starwise_distances[m_name] = starwise_dist

# Boxplot comparing per-star distances across all methods
plt.figure(figsize=(10, 6))
labels = list(method_starwise_distances.keys())
dist_data = [method_starwise_distances[m] for m in labels]
plt.boxplot(dist_data, labels=labels, vert=True)
plt.xticks(rotation=45)
plt.semilogy()
plt.ylabel("Reconstruction Distance (L2 norm)")
plt.title("Distribution of Per-Star Reconstruction Distances for Each Method")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_157221/3872053285.py:22: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(dist_data, labels=labels, vert=True)

# %%
method_explained_variances = {}

for m_name, data_dict in results.items():
    all_preds = data_dict["all_preds"]  # shape [N_test, 17]
    all_true = data_dict["all_true"]    # shape [N_test, 17]

    # If it's already in the dictionary:
    if "explained_variance" in data_dict:
        ev = data_dict["explained_variance"]
    else:
        # Calculate it if not stored
        cov_matrix = np.cov(all_true, rowvar=False)
        total_variance = np.trace(cov_matrix)
        mse_global = np.mean((all_preds - all_true)**2)
        explained_variance = 1 - (mse_global / total_variance)

    method_explained_variances[m_name] = ev

# Plot a bar chart of explained variance for each method
plt.figure(figsize=(8, 5))
labels = list(method_explained_variances.keys())
ev_values = [method_explained_variances[m] for m in labels]
plt.bar(range(len(labels)), ev_values, color='skyblue')
plt.xticks(range(len(labels)), labels, rotation=45, ha='right')
plt.ylabel("Explained Variance")
plt.semilogy()
plt.title("Explained Variance Comparison Across Methods")
plt.tight_layout()
plt.show()
