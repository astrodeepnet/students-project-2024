# %%
from astropy.io import fits
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from scipy.stats import shapiro

# %%
hdulist = fits.open('../../data/allStarLite-dr17-synspec_rev1.fits')

# %%
hdu1_data = hdulist[1].data

# %%
df4 = pd.DataFrame(hdu1_data.tolist(), columns=hdu1_data.names)

# %%
df = df4

# %%
df = df.drop_duplicates(subset=['APOGEE_ID'])

# %%
df_classes= pd.read_csv("../../data/classes.csv")

# %%
df_classes
# Out:
#                  apogee_id class_spectral class_lum_logg class_lum_jhk  \
# 0       2M00000019-1924498              G              V            Ia
# 1       2M00000032+5737103              F              V            II
# 2       2M00000032+5737103              F              V            II
# 3       2M00000068+5710233              K             IV            II
# 4       2M00000103+1525513              G              V           III
# ...                    ...            ...            ...           ...
# 594006  2M23595837+5700444              K            III            II
# 594007  2M23595846+1503028              G              V           III
# 594008  2M23595886+5726058              K            III            II
# 594009  2M23595921+5609479              K            III            II
# 594010  2M23595980+1528407              F              V           III
#
#         class_lum_bins_logg  class_lum_bins_jhk
# 0                         7                   3
# 1                         6                   3
# 2                         6                   3
# 3                         5                   3
# 4                         6                   4
# ...                     ...                 ...
# 594006                    3                   5
# 594007                    7                   4
# 594008                    3                   4
# 594009                    3                   4
# 594010                    6                   3
#
# [594011 rows x 6 columns]

# %%
df
# Out:
#                  APOGEE_ID TELESCOPE        FIELD ALT_ID          RA  \
# 0                    VESTA     apo1m  calibration                NaN
# 1       2M00000002+7417074    apo25m       120+12   none    0.000103
# 2       2M00000019-1924498    apo25m       060-75   none    0.000832
# 3       2M00000032+5737103    apo25m       116-04   none    0.001335
# 5       2M00000035-7323394    lco25m        SMC12   none    0.001467
# ...                    ...       ...          ...    ...         ...
# 733896  2M23595886-2009435    apo25m       060-75   none  359.995258
# 733897  2M23595886+5726058    apo25m       116-04   none  359.995265
# 733898  2M23595921+5609479    apo25m  NGC7789_MGA   none  359.996744
# 733899  2M23595949-7342592    lco25m        SMC12   none  359.997887
# 733900  2M23595980+1528407    apo25m       105-45   none  359.999181
#
#               DEC        GLON       GLAT          J  J_ERR  ...  NI_FE_ERR  \
# 0             NaN  292.219131 -30.602919  99.999001  0.000  ...   0.010266
# 1       74.285408  119.401807  11.767414   8.597000  0.039  ...   0.010609
# 2      -19.413851   63.394122 -75.906397  11.074000  0.022  ...   0.013835
# 3       57.619530  116.065371  -4.564768  10.905000  0.023  ...   0.016555
# 5      -73.394287  307.939441 -43.230305  15.008000  0.045  ...   0.053997
# ...           ...         ...        ...        ...    ...  ...        ...
# 733896 -20.162107   60.806239 -76.324013  11.788000  0.022  ...        NaN
# 733897  57.434956  116.025359  -4.745011  11.466000  0.024  ...   0.011980
# 733898  56.163330  115.771964  -5.991363  11.985000  0.023  ...   0.017686
# 733899 -73.716454  307.821174 -42.919934  15.924000  0.094  ...   0.049855
# 733900  15.477974  105.077690 -45.602838  10.786000  0.023  ...   0.020078
#
#         NI_FE_FLAG  CU_FE  CU_FE_SPEC  CU_FE_ERR CU_FE_FLAG     CE_FE  \
# 0                0    NaN         NaN   0.059403          2       NaN
# 1                0    NaN         NaN   0.001221          2       NaN
# 2                0    NaN         NaN   0.102594          2       NaN
# 3                0    NaN         NaN   0.123839          2       NaN
# 5                0    NaN         NaN   0.276795          2 -0.155160
# ...            ...    ...         ...        ...        ...       ...
# 733896           0    NaN         NaN        NaN        258       NaN
# 733897           0    NaN         NaN        NaN        259 -0.058750
# 733898           0    NaN         NaN        NaN        259 -0.103446
# 733899           0    NaN         NaN   0.174322          2  0.107710
# 733900           0    NaN         NaN   0.289108          2       NaN
#
#         CE_FE_SPEC  CE_FE_ERR  CE_FE_FLAG
# 0              NaN        NaN          64
# 1              NaN        NaN          64
# 2              NaN        NaN          64
# 3              NaN        NaN          64
# 5        -0.099500   0.146837           0
# ...            ...        ...         ...
# 733896         NaN        NaN          64
# 733897   -0.003090   0.072443           0
# 733898   -0.047786   0.097572           0
# 733899    0.163370   0.140188           0
# 733900         NaN        NaN          64
#
# [657135 rows x 191 columns]

# %%
# Fusionner les DataFrames avec une fusion gauche
df_merged = pd.merge(df_classes, df, left_on='apogee_id', right_on='APOGEE_ID', how='inner')

# %%
df_merged
# Out:
#                  apogee_id class_spectral class_lum_logg class_lum_jhk  \
# 0       2M00000019-1924498              G              V            Ia
# 1       2M00000032+5737103              F              V            II
# 2       2M00000032+5737103              F              V            II
# 3       2M00000068+5710233              K             IV            II
# 4       2M00000103+1525513              G              V           III
# ...                    ...            ...            ...           ...
# 594006  2M23595837+5700444              K            III            II
# 594007  2M23595846+1503028              G              V           III
# 594008  2M23595886+5726058              K            III            II
# 594009  2M23595921+5609479              K            III            II
# 594010  2M23595980+1528407              F              V           III
#
#         class_lum_bins_logg  class_lum_bins_jhk           APOGEE_ID TELESCOPE  \
# 0                         7                   3  2M00000019-1924498    apo25m
# 1                         6                   3  2M00000032+5737103    apo25m
# 2                         6                   3  2M00000032+5737103    apo25m
# 3                         5                   3  2M00000068+5710233    apo25m
# 4                         6                   4  2M00000103+1525513    apo25m
# ...                     ...                 ...                 ...       ...
# 594006                    3                   5  2M23595837+5700444    apo25m
# 594007                    7                   4  2M23595846+1503028    apo25m
# 594008                    3                   4  2M23595886+5726058    apo25m
# 594009                    3                   4  2M23595921+5609479    apo25m
# 594010                    6                   3  2M23595980+1528407    apo25m
#
#               FIELD ALT_ID  ...  NI_FE_ERR  NI_FE_FLAG  CU_FE  CU_FE_SPEC  \
# 0            060-75   none  ...   0.013835           0    NaN         NaN
# 1            116-04   none  ...   0.016555           0    NaN         NaN
# 2            116-04   none  ...   0.016555           0    NaN         NaN
# 3             N7789   none  ...   0.011601           0    NaN         NaN
# 4        107-46_MGA   none  ...   0.019600           0    NaN         NaN
# ...             ...    ...  ...        ...         ...    ...         ...
# 594006        N7789   none  ...   0.022493           0    NaN         NaN
# 594007   107-46_MGA   none  ...   0.023919           0    NaN         NaN
# 594008       116-04   none  ...   0.011980           0    NaN         NaN
# 594009  NGC7789_MGA   none  ...   0.017686           0    NaN         NaN
# 594010       105-45   none  ...   0.020078           0    NaN         NaN
#
#         CU_FE_ERR  CU_FE_FLAG     CE_FE  CE_FE_SPEC  CE_FE_ERR  CE_FE_FLAG
# 0        0.102594           2       NaN         NaN        NaN          64
# 1        0.123839           2       NaN         NaN        NaN          64
# 2        0.123839           2       NaN         NaN        NaN          64
# 3        0.004401           2 -0.055580    0.000080   0.086572           0
# 4        0.133414           2       NaN         NaN        NaN          64
# ...           ...         ...       ...         ...        ...         ...
# 594006   0.016774           2 -0.035640    0.020020   0.141408           0
# 594007   0.077250           2       NaN         NaN        NaN          64
# 594008        NaN         259 -0.058750   -0.003090   0.072443           0
# 594009        NaN         259 -0.103446   -0.047786   0.097572           0
# 594010   0.289108           2       NaN         NaN        NaN          64
#
# [594011 rows x 197 columns]

# %%
df = df_merged

# %%
variable_selection = ["J", "H", "K","LOGG", "M_H", "VMICRO", "VMACRO", 'C_FE', 'CI_FE', 'N_FE', 'O_FE', 'NA_FE', 'MG_FE', 'AL_FE', 'SI_FE', 'S_FE', 'K_FE', 'CA_FE', 
    'TI_FE', 'V_FE', 'CR_FE', 'MN_FE', 'NI_FE', 'FE_H']

variable_classe =["apogee_id","class_spectral","class_lum_logg","class_lum_jhk","class_lum_bins_logg","class_lum_bins_jhk"]

variable_normalise = ["M_H","VMICRO","VMACRO"]

# %%
df = df[variable_normalise]

# %%
df.hist(figsize=(15, 12), bins=30, edgecolor='black')
plt.suptitle('Distribution df',fontsize=16)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#print("Valeurs abberantes J :",(df["J"] > 30).sum())
#print("Valeurs abberantes H :",(df["H"] > 30).sum())
#print("Valeurs abberantes K :",(df["K"] > 30).sum())
#Drop  les lignes?

# %%
# Créer un objet StandardScaler
scaler = StandardScaler()

# Appliquer la standardisation à toutes les colonnes du DataFrame
df_standardized = scaler.fit_transform(df)

# Convertir le résultat en DataFrame pour conserver les noms de colonnes
df_standardized = pd.DataFrame(df_standardized, columns=df.columns)

# %%
df_standardized.hist(figsize=(15, 12), bins=30, edgecolor='black')
plt.suptitle('Distribution df standardisé',fontsize=16)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Créer un objet MinMaxScaler
scaler = MinMaxScaler()

# Appliquer la normalisation Min-Max à toutes les colonnes du DataFrame
df_normalized = scaler.fit_transform(df)

# Convertir le résultat en DataFrame pour conserver les noms de colonnes
df_normalized = pd.DataFrame(df_normalized, columns=df.columns)

# %%
df_normalized.hist(figsize=(15, 12), bins=30, edgecolor='black')
plt.suptitle('Distribution df normalizé Min-Max',fontsize=16)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_standardized.describe()
# Out:
#                 M_H        VMICRO        VMACRO
# count  5.704300e+05  5.940110e+05  5.940110e+05
# mean  -1.661666e-16 -1.517710e-16 -1.224886e-17
# std    1.000001e+00  1.000001e+00  1.000001e+00
# min   -6.387543e+00 -1.338218e+00 -9.776324e-01
# 25%   -4.681201e-01 -1.030323e+00 -9.776324e-01
# 50%    1.360456e-01  1.070643e-01  3.251789e-01
# 75%    6.454674e-01  6.371251e-01  7.729363e-01
# max    3.337876e+00  6.278540e+00  5.471473e+00

# %%
df_normalized.describe()
# Out:
#                  M_H         VMICRO         VMACRO
# count  570430.000000  594011.000000  594011.000000
# mean        0.656788       0.175694       0.151592
# std         0.102823       0.131290       0.155060
# min         0.000000       0.000000       0.000000
# 25%         0.608655       0.040423       0.000000
# 50%         0.670777       0.189750       0.202014
# 75%         0.723158       0.259342       0.271444
# max         1.000000       1.000000       1.000000

# %%
# Initialiser un dictionnaire pour stocker les résultats
normality_results = {}

# Parcourir les colonnes numériques du DataFrame
for col in df.columns:
    stat, p_value = shapiro(df[col].dropna())  # Tester en ignorant les NaN
    normality_results[col] = {"statistic": stat, "p_value": p_value}

# Convertir les résultats en DataFrame pour les visualiser
results_df = pd.DataFrame(normality_results).T
results_df["normality"] = results_df["p_value"] > 0.05  # True si les données suivent une loi normale

# Afficher les résultats
print(results_df)
# Out:
#         statistic        p_value  normality
# M_H      0.893936  5.217422e-148      False
# VMICRO   0.913939  4.931105e-142      False
# VMACRO   0.804367  6.309135e-169      False
# C:\Users\Maxime\anaconda3\envs\python312GPU\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 570430.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\Maxime\anaconda3\envs\python312GPU\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 594011.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
# Initialiser un dictionnaire pour stocker les résultats
normality_results = {}

# Parcourir les colonnes numériques du DataFrame
for col in df_standardized.columns:
    stat, p_value = shapiro(df_standardized[col].dropna())  # Tester en ignorant les NaN
    normality_results[col] = {"statistic": stat, "p_value": p_value}

# Convertir les résultats en DataFrame pour les visualiser
results_df = pd.DataFrame(normality_results).T
results_df["normality"] = results_df["p_value"] > 0.05  # True si les données suivent une loi normale

# Afficher les résultats
print(results_df)
# Out:
#         statistic        p_value  normality
# M_H      0.893936  5.217422e-148      False
# VMICRO   0.913939  4.931105e-142      False
# VMACRO   0.804367  6.309135e-169      False
# C:\Users\Maxime\anaconda3\envs\python312GPU\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 570430.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\Maxime\anaconda3\envs\python312GPU\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 594011.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
# Initialiser un dictionnaire pour stocker les résultats
normality_results = {}

# Parcourir les colonnes numériques du DataFrame
for col in df_normalized.columns:
    stat, p_value = shapiro(df_normalized[col].dropna())  # Tester en ignorant les NaN
    normality_results[col] = {"statistic": stat, "p_value": p_value}

# Convertir les résultats en DataFrame pour les visualiser
results_df = pd.DataFrame(normality_results).T
results_df["normality"] = results_df["p_value"] > 0.05  # True si les données suivent une loi normale

# Afficher les résultats
print(results_df)
# Out:
#         statistic        p_value  normality
# M_H      0.893936  5.217422e-148      False
# VMICRO   0.913939  4.931105e-142      False
# VMACRO   0.804367  6.309135e-169      False
# C:\Users\Maxime\anaconda3\envs\python312GPU\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 570430.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\Maxime\anaconda3\envs\python312GPU\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 594011.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
# Calculer la matrice de corrélation de Pearson
correlation_matrix = df.corr(method='pearson')

# Augmenter la taille de la figure et ajuster les paramètres pour une meilleure lisibilité
plt.figure(figsize=(12, 10))  # Taille de la figure
sns.heatmap(
    correlation_matrix,
    annot=True,               # Afficher les valeurs numériques
    fmt=".2f",                # Formater les nombres à 2 décimales
    annot_kws={"size": 8},    # Réduire la taille des annotations
    cmap='coolwarm',          # Palette de couleurs
    cbar=True,                # Afficher la barre de couleur
    square=True               # Garder les cellules carrées
)
plt.xticks(rotation=45, fontsize=10)  # Incliner les noms des colonnes pour éviter le chevauchement
plt.yticks(fontsize=10)               # Ajuster la taille des noms des lignes
plt.title("Matrice de corrélation de Pearson", fontsize=14)  # Titre plus lisible
plt.tight_layout()  # Réduire les marges
plt.show()

# %%
# Calculer la matrice de corrélation de Pearson
correlation_matrix = df_standardized.corr(method='pearson')

# Augmenter la taille de la figure et ajuster les paramètres pour une meilleure lisibilité
plt.figure(figsize=(12, 10))  # Taille de la figure
sns.heatmap(
    correlation_matrix,
    annot=True,               # Afficher les valeurs numériques
    fmt=".2f",                # Formater les nombres à 2 décimales
    annot_kws={"size": 8},    # Réduire la taille des annotations
    cmap='coolwarm',          # Palette de couleurs
    cbar=True,                # Afficher la barre de couleur
    square=True               # Garder les cellules carrées
)
plt.xticks(rotation=45, fontsize=10)  # Incliner les noms des colonnes pour éviter le chevauchement
plt.yticks(fontsize=10)               # Ajuster la taille des noms des lignes
plt.title("Matrice de corrélation de Pearson", fontsize=14)  # Titre plus lisible
plt.tight_layout()  # Réduire les marges
plt.show()

# %%
# Calculer la matrice de corrélation de Pearson
correlation_matrix = df_normalized.corr(method='pearson')

# Augmenter la taille de la figure et ajuster les paramètres pour une meilleure lisibilité
plt.figure(figsize=(12, 10))  # Taille de la figure
sns.heatmap(
    correlation_matrix,
    annot=True,               # Afficher les valeurs numériques
    fmt=".2f",                # Formater les nombres à 2 décimales
    annot_kws={"size": 8},    # Réduire la taille des annotations
    cmap='coolwarm',          # Palette de couleurs
    cbar=True,                # Afficher la barre de couleur
    square=True               # Garder les cellules carrées
)
plt.xticks(rotation=45, fontsize=10)  # Incliner les noms des colonnes pour éviter le chevauchement
plt.yticks(fontsize=10)               # Ajuster la taille des noms des lignes
plt.title("Matrice de corrélation de Pearson", fontsize=14)  # Titre plus lisible
plt.tight_layout()  # Réduire les marges
plt.show()

# %% [markdown]
# Normalisation en fonction de la méthode de machine learning : DBSCAN = MinMax / K-means et K-medoids = Standardisation

# %%
df_normalized.head()

# %%
df_normalized.to_csv("../../data/df_normalized.csv", index=False)
