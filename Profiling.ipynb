# %%
from astropy.io import fits
import pandas as pd
import matplotlib.pyplot as plt

# %%
hdulist = fits.open('d:/users/22106407t/Downloads/allStarLite-dr17-synspec_rev1.fits')

# %%
hdu1_data = hdulist[1].data

# %%
df4 = pd.DataFrame(hdu1_data.tolist(), columns=hdu1_data.names)

# %%
df = df4

# %%
df.head()
# Out:
#             APOGEE_ID TELESCOPE        FIELD ALT_ID        RA        DEC  \
# 0               VESTA     apo1m  calibration              NaN        NaN
# 1  2M00000002+7417074    apo25m       120+12   none  0.000103  74.285408
# 2  2M00000019-1924498    apo25m       060-75   none  0.000832 -19.413851
# 3  2M00000032+5737103    apo25m       116-04   none  0.001335  57.619530
# 4  2M00000032+5737103    apo25m        N7789   none  0.001335  57.619530
#
#          GLON       GLAT          J  J_ERR  ...  NI_FE_ERR  NI_FE_FLAG  CU_FE  \
# 0  292.219131 -30.602919  99.999001  0.000  ...   0.010266           0    NaN
# 1  119.401807  11.767414   8.597000  0.039  ...   0.010609           0    NaN
# 2   63.394122 -75.906397  11.074000  0.022  ...   0.013835           0    NaN
# 3  116.065371  -4.564768  10.905000  0.023  ...   0.016555           0    NaN
# 4  116.065371  -4.564768  10.905000  0.023  ...   0.012638           0    NaN
#
#    CU_FE_SPEC  CU_FE_ERR CU_FE_FLAG  CE_FE  CE_FE_SPEC  CE_FE_ERR  CE_FE_FLAG
# 0         NaN   0.059403          2    NaN         NaN        NaN          64
# 1         NaN   0.001221          2    NaN         NaN        NaN          64
# 2         NaN   0.102594          2    NaN         NaN        NaN          64
# 3         NaN   0.123839          2    NaN         NaN        NaN          64
# 4         NaN   0.107103          2    NaN         NaN        NaN          64
#
# [5 rows x 191 columns]

# %%
df.describe()
# Out:
#                   RA            DEC           GLON           GLAT  \
# count  733900.000000  733900.000000  733901.000000  733901.000000
# mean      179.031201       6.688964     161.564433       7.680005
# std        96.801018      39.649117     101.804392      35.064978
# min         0.000103     -87.224808       0.000088     -89.909116
# 25%        93.116921     -22.628102      74.885580     -15.130762
# 50%       181.898395      11.996523     160.183732       3.276527
# 75%       265.892360      39.576674     241.210803      32.805555
# max       359.999181      87.608246     359.999832      89.931476
#
#                    J          J_ERR              H          H_ERR  \
# count  723596.000000  722680.000000  733886.000000  722006.000000
# mean       11.543006       0.024710      10.840332       0.026333
# std         3.873045       0.029999       1.861256       0.042978
# min         5.180000       0.000000       0.358000       0.000000
# 25%        10.446000       0.022000       9.925000       0.022000
# 50%        11.445000       0.023000      10.889000       0.024000
# 75%        12.440000       0.026000      11.796000       0.028000
# max        99.999001       9.998000      99.999001       9.999000
#
#                    K          K_ERR  ...      NI_FE_ERR     NI_FE_FLAG  CU_FE  \
# count  723589.000000  721512.000000  ...  633827.000000  733901.000000    0.0
# mean       10.759167       0.023649  ...       0.018935       8.776377    NaN
# std         3.869474       0.076668  ...       0.010740      36.981835    NaN
# min         4.382000       0.000000  ...       0.005889       0.000000    NaN
# 25%         9.746000       0.019000  ...       0.012312       0.000000    NaN
# 50%        10.712000       0.021000  ...       0.016329       0.000000    NaN
# 75%        11.555000       0.024000  ...       0.022474       0.000000    NaN
# max        99.999001       9.998000  ...       1.736116     355.000000    NaN
#
#        CU_FE_SPEC      CU_FE_ERR     CU_FE_FLAG          CE_FE     CE_FE_SPEC  \
# count         0.0  442416.000000  733901.000000  353995.000000  353995.000000
# mean          NaN       0.103878      95.555146      -0.120582      -0.064922
# std           NaN       0.608181     125.064670       0.270995       0.270995
# min           NaN       0.000587       0.000000      -2.510510      -2.454850
# 25%           NaN       0.013521       2.000000      -0.228593      -0.172932
# 50%           NaN       0.054230       2.000000      -0.117369      -0.061709
# 75%           NaN       0.092658     259.000000       0.001460       0.057120
# max           NaN      60.004436     291.000000       2.913390       2.969050
#
#            CE_FE_ERR     CE_FE_FLAG
# count  353995.000000  733901.000000
# mean        0.103885      35.717042
# std         0.131483      48.138724
# min         0.027156       0.000000
# 25%         0.061052       0.000000
# 50%         0.083012       0.000000
# 75%         0.118397      64.000000
# max         3.046578     354.000000
#
# [8 rows x 169 columns]

# %%
display(df.columns)
# Out:
# Index(['APOGEE_ID', 'TELESCOPE', 'FIELD', 'ALT_ID', 'RA', 'DEC', 'GLON',
#        'GLAT', 'J', 'J_ERR',
#        ...
#        'NI_FE_ERR', 'NI_FE_FLAG', 'CU_FE', 'CU_FE_SPEC', 'CU_FE_ERR',
#        'CU_FE_FLAG', 'CE_FE', 'CE_FE_SPEC', 'CE_FE_ERR', 'CE_FE_FLAG'],
#       dtype='object', length=191)

# %%
df.dtypes
# Out:
# APOGEE_ID      object
# TELESCOPE      object
# FIELD          object
# ALT_ID         object
# RA            float64
#                ...
# CU_FE_FLAG      int64
# CE_FE         float64
# CE_FE_SPEC    float64
# CE_FE_ERR     float64
# CE_FE_FLAG      int64
# Length: 191, dtype: object

# %%
df = df4

# %%
# subset all chemical abundances (collumn name contain "_FE")
chemical_subset = df.filter(regex='_FE', axis=1) 

# merge with + df.filter(regex='_H', axis=1)
chemical_subset = pd.concat([chemical_subset, df.filter(regex='_H', axis=1)], axis=1)

# create a df without the chemical abundances
df_no_chemical = df.drop(chemical_subset.columns, axis=1)

# %%
df = df_no_chemical

# %%
missing_values = df.isnull().sum()

chemical_subset_missing_values = chemical_subset.isnull().sum()

# %%
missing_values = missing_values[missing_values > 0]    

missing_values.sort_values(ascending=False, inplace=True)

chemical_subset_missing_values = chemical_subset_missing_values[chemical_subset_missing_values > 0]

chemical_subset_missing_values.sort_values(ascending=False, inplace=True)

# %%
if len(missing_values) > 0:

    plt.figure(figsize=(15, 8))  
    missing_values.plot(kind='bar')

    plt.title('Nombre de valeurs nulles par colonne')
    plt.xlabel('Nom des colonnes')
    plt.ylabel('Nombre de valeurs nulles')
    plt.xticks( ha='right', fontsize=8)  
    


    plt.tight_layout()  # Assure que tout s'affiche bien dans la figure
    plt.show()

# %%
if len(chemical_subset_missing_values) > 0:

    plt.figure(figsize=(15, 8))  
    chemical_subset_missing_values.plot(kind='bar')

    plt.title('Nombre de valeurs nulles par colonne')
    plt.xlabel('Nom des colonnes')
    plt.ylabel('Nombre de valeurs nulles')
    plt.xticks( ha='right', fontsize=8)  


    plt.tight_layout()  # Assure que tout s'affiche bien dans la figure
    plt.show()

# %%
low_variability_columns = []

for col in df.columns:
    try:
        # Si la colonne contient moins de 5 valeurs uniques, on l'ajoute à la liste
        if df[col].nunique() < 5:
            low_variability_columns.append(col)
    except TypeError:
        print(f"error with column {col}")

print("Colonnes avec faible variabilité :", low_variability_columns)
# Out:
# error with column PARAMFLAG
# error with column X_M
# error with column X_M_ERR
# error with column ELEM_CHI2
# error with column ELEMFRAC
# error with column X_M_SPEC
# Colonnes avec faible variabilité : ['TELESCOPE', 'APOGEE2_TARGET4', 'RV_ALPHA', 'RV_CARB', 'MAX_JK']

# %%
# create an error dataset containing all errors 
chemical_errors_subset = chemical_subset.filter(regex='_ERR', axis=1)

# create an error dataset containing all specs
chemical_specs_subset = chemical_subset.filter(regex='_SPEC', axis=1)

# create a dataset containing all the flags
flags_subset = chemical_subset.filter(regex='FLAG', axis=1)

# remove flags, err and spec from the chemical_subset
chemical_subset = chemical_subset.drop(chemical_errors_subset.columns, axis=1)
chemical_subset = chemical_subset.drop(chemical_specs_subset.columns, axis=1)
chemical_subset = chemical_subset.drop(flags_subset.columns, axis=1)

# %%
flags_subset.hist(figsize=(15, 12), bins=30, edgecolor='black')
plt.tight_layout()
plt.show()

# %%
chemical_specs_subset.hist(figsize=(15, 12), bins=30, edgecolor='black')
plt.tight_layout()
plt.show()

# %%
chemical_errors_subset.hist(figsize=(15, 12), bins=30, edgecolor='black')
plt.tight_layout()
plt.show()

# %%
chemical_subset.hist(figsize=(15, 12), bins=30, edgecolor='black')
plt.tight_layout()
plt.show()

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                  APOGEE_ID TELESCOPE        FIELD ALT_ID          RA  \
# 0                    VESTA     apo1m  calibration                NaN
# 1       2M00000002+7417074    apo25m       120+12   none    0.000103
# 2       2M00000019-1924498    apo25m       060-75   none    0.000832
# 3       2M00000032+5737103    apo25m       116-04   none    0.001335
# 4       2M00000032+5737103    apo25m        N7789   none    0.001335
# ...                    ...       ...          ...    ...         ...
# 733896  2M23595886-2009435    apo25m       060-75   none  359.995258
# 733897  2M23595886+5726058    apo25m       116-04   none  359.995265
# 733898  2M23595921+5609479    apo25m  NGC7789_MGA   none  359.996744
# 733899  2M23595949-7342592    lco25m        SMC12   none  359.997887
# 733900  2M23595980+1528407    apo25m       105-45   none  359.999181
#
#               DEC        GLON       GLAT          J  J_ERR  ...   TEFF_ERR  \
# 0             NaN  292.219131 -30.602919  99.999001  0.000  ...  25.380983
# 1       74.285408  119.401807  11.767414   8.597000  0.039  ...   4.060303
# 2      -19.413851   63.394122 -75.906397  11.074000  0.022  ...  25.553564
# 3       57.619530  116.065371  -4.564768  10.905000  0.023  ...  45.847328
# 4       57.619530  116.065371  -4.564768  10.905000  0.023  ...  41.753815
# ...           ...         ...        ...        ...    ...  ...        ...
# 733896 -20.162107   60.806239 -76.324013  11.788000  0.022  ...        NaN
# 733897  57.434956  116.025359  -4.745011  11.466000  0.024  ...   9.050734
# 733898  56.163330  115.771964  -5.991363  11.985000  0.023  ...  11.298859
# 733899 -73.716454  307.821174 -42.919934  15.924000  0.094  ...  18.433924
# 733900  15.477974  105.077690 -45.602838  10.786000  0.023  ...  59.489235
#
#             LOGG  LOGG_ERR   ALPHA_M  ALPHA_M_ERR    VMICRO    VMACRO  \
# 0       4.428520  0.019974  0.006679     0.006518  0.412648  0.000000
# 1       0.904598  0.021523  0.036922     0.004735  1.712182  3.223484
# 2       4.304115  0.024555  0.090978     0.007373  0.409694  0.000000
# 3       3.673970  0.030661  0.029159     0.011755  2.143433  0.000000
# 4       3.715561  0.025935  0.048066     0.009856  1.957898  0.000000
# ...          ...       ...       ...          ...       ...       ...
# 733896       NaN       NaN       NaN          NaN       NaN       NaN
# 733897  2.480687  0.024013  0.065434     0.006152  1.557435  3.381057
# 733898  2.571437  0.028686  0.037709     0.007182  1.212665  2.756312
# 733899  1.334888  0.077052 -0.019310     0.023462  2.197000  5.439030
# 733900  3.972290  0.038770  0.238005     0.014992  1.472448  0.000000
#
#             VSINI    TEFF_SPEC  LOGG_SPEC
# 0        4.778923  5766.799805     4.3832
# 1             NaN  3621.699951     1.0245
# 2        6.273645  5522.399902     4.1950
# 3       14.965801  6210.700195     3.5259
# 4       14.993395  6284.100098     3.5585
# ...           ...          ...        ...
# 733896        NaN          NaN        NaN
# 733897        NaN  4789.000000     2.5966
# 733898        NaN  4502.899902     2.7153
# 733899        NaN  4342.799805     1.2616
# 733900  11.603794  6384.000000     3.9058
#
# [733901 rows x 93 columns]>

# %%
df.hist(figsize=(15, 12), bins=30, edgecolor='black')
plt.tight_layout()
plt.show()

# %%
# create an error dataset containing all errors 
df_errors = df.filter(regex='_ERR', axis=1)

# create an error dataset containing all spec  (QUE 2 DONNEES -> pas pertinent  ?)
df_spec = df.filter(regex='_SPEC', axis=1)

# create an error dataset containing all apogee 
df_apogee = df.filter(regex='APOGEE', axis=1)

# create an error dataset containing all gaia (autre df release par l'ESA en 2018)
df_gaia = df.filter(regex='GAIA', axis=1)

# create an error dataset containing all RV 
df_rv = df.filter(regex='RV', axis=1)

# %%
df = df.drop(df_errors.columns, axis=1, errors='ignore')
df = df.drop(df_apogee.columns, axis=1, errors='ignore')
df = df.drop(df_gaia.columns, axis=1, errors='ignore')
df = df.drop(df_rv.columns, axis=1, errors='ignore')
# Out:
# "df = df.drop(df_errors.columns, axis=1, errors='ignore')\ndf = df.drop(df_apogee.columns, axis=1, errors='ignore')\ndf = df.drop(df_gaia.columns, axis=1, errors='ignore')\ndf = df.drop(df_rv.columns, axis=1, errors='ignore')"

# %%
df_errors.hist(figsize=(15, 12), bins=30, edgecolor='black')
plt.tight_layout()
plt.show()

# %%
df_apogee.hist(figsize=(15, 12), bins=30, edgecolor='black')
plt.tight_layout()
plt.show()

# %%
df_gaia.hist(figsize=(15, 12), bins=30, edgecolor='black')
plt.tight_layout()
plt.show()

# %%
df_rv.hist(figsize=(15, 12), bins=30, edgecolor='black')
plt.tight_layout()
plt.show()

# %%
df.hist(figsize=(15, 12), bins=30, edgecolor='black')
plt.tight_layout()
plt.show()

# %%
df.describe()
# Out:
#                   RA            DEC           GLON           GLAT  \
# count  733900.000000  733900.000000  733901.000000  733901.000000
# mean      179.031201       6.688964     161.564433       7.680005
# std        96.801018      39.649117     101.804392      35.064978
# min         0.000103     -87.224808       0.000088     -89.909116
# 25%        93.116921     -22.628102      74.885580     -15.130762
# 50%       181.898395      11.996523     160.183732       3.276527
# 75%       265.892360      39.576674     241.210803      32.805555
# max       359.999181      87.608246     359.999832      89.931476
#
#                    J          J_ERR              H          H_ERR  \
# count  723596.000000  722680.000000  733886.000000  722006.000000
# mean       11.543006       0.024710      10.840332       0.026333
# std         3.873045       0.029999       1.861256       0.042978
# min         5.180000       0.000000       0.358000       0.000000
# 25%        10.446000       0.022000       9.925000       0.022000
# 50%        11.445000       0.023000      10.889000       0.024000
# 75%        12.440000       0.026000      11.796000       0.028000
# max        99.999001       9.998000      99.999001       9.999000
#
#                    K          K_ERR  ...       TEFF_ERR           LOGG  \
# count  723589.000000  721512.000000  ...  689024.000000  689024.000000
# mean       10.759167       0.023649  ...      26.924606       3.082897
# std         3.869474       0.076668  ...      68.518377       1.234761
# min         4.382000       0.000000  ...       2.461126      -0.482825
# 25%         9.746000       0.019000  ...       8.451615       2.278944
# 50%        10.712000       0.021000  ...      12.657253       2.984478
# 75%        11.555000       0.024000  ...      24.477957       4.314916
# max        99.999001       9.998000  ...   11277.411133       5.391378
#
#             LOGG_ERR        ALPHA_M    ALPHA_M_ERR         VMICRO  \
# count  689024.000000  646591.000000  646591.000000  689024.000000
# mean        0.034049       0.071228       0.029290       1.152248
# std         0.044472       0.104415       0.107010       0.665692
# min         0.010315      -0.714365       0.001972       0.299999
# 25%         0.023135       0.004136       0.006117       0.545858
# 50%         0.027429       0.041616       0.008338       1.187385
# 75%         0.034414       0.108675       0.013209       1.510463
# max         6.477190       0.995405      19.249155       4.799986
#
#               VMACRO          VSINI      TEFF_SPEC      LOGG_SPEC
# count  689024.000000  316812.000000  689024.000000  689024.000000
# mean        1.986807      10.734419    4948.365630       3.065823
# std         2.040843      20.747286    1402.585090       1.161138
# min         0.000000       1.499996    3012.500000      -0.437240
# 25%         0.000000       1.549173    4260.100098       2.351700
# 50%         2.593465       3.137979    4710.899902       3.052900
# 75%         3.498560       7.348903    5195.799805       4.219300
# max        12.765858      96.006363   19937.000000       5.437300
#
# [8 rows x 74 columns]

# %%
to_delete = ['ALT_ID','APOGEE_TARGET1','APOGEE_TARGET2','APOGEE2_TARGET1','APOGEE2_TARGET2','APOGEE2_TARGET3','APOGEE2_TARGET4','PROGRAMNAME','RV_TEFF','RV_LOGG','RV_ALPHA','RV_CARB','SNREV','SFD_EBV','RV_CCFWHM','RV_AUTOFWHM','N_COMPONENTS','MEANFIB','SIGFIB','ASPCAP_GRID','ASPCAPFLAG','ASPCAP_CHI2','EXTRATARG','FRAC_BADPIX','FRAC_LOWSNR','FRAC_SIGSKY']
to_delete_gaia = ['GAIAEDR3_SOURCE_ID', 'GAIAEDR3_PARALLAX', 'GAIAEDR3_PARALLAX_ERROR','GAIAEDR3_PMRA', 'GAIAEDR3_PMRA_ERROR', 'GAIAEDR3_PMDEC','GAIAEDR3_PMDEC_ERROR', 'GAIAEDR3_PHOT_G_MEAN_MAG','GAIAEDR3_PHOT_BP_MEAN_MAG', 'GAIAEDR3_PHOT_RP_MEAN_MAG','GAIAEDR3_DR2_RADIAL_VELOCITY', 'GAIAEDR3_DR2_RADIAL_VELOCITY_ERROR','GAIAEDR3_R_MED_GEO', 'GAIAEDR3_R_LO_GEO', 'GAIAEDR3_R_MED_PHOTOGEO','GAIAEDR3_R_LO_PHOTOGEO']

# %%
df = df.drop(to_delete, axis=1, errors='ignore')
df = df.drop(to_delete_gaia, axis=1, errors='ignore')
