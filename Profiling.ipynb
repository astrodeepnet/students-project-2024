# %%
from astropy.io import fits
import pandas as pd
import matplotlib.pyplot as plt

# %%
hdulist = fits.open('data/allStarLite-dr17-synspec_rev1.fits')

# %%
hdu1_data = hdulist[1].data

# %%
df4 = pd.DataFrame(hdu1_data.tolist(), columns=hdu1_data.names)

# %%
df = df4

# %%
df.head()
# Out:
#             APOGEE_ID TELESCOPE        FIELD ALT_ID        RA        DEC  \
# 0               VESTA     apo1m  calibration              NaN        NaN
# 1  2M00000002+7417074    apo25m       120+12   none  0.000103  74.285408
# 2  2M00000019-1924498    apo25m       060-75   none  0.000832 -19.413851
# 3  2M00000032+5737103    apo25m       116-04   none  0.001335  57.619530
# 4  2M00000032+5737103    apo25m        N7789   none  0.001335  57.619530
#
#          GLON       GLAT          J  J_ERR  ...  NI_FE_ERR  NI_FE_FLAG  CU_FE  \
# 0  292.219131 -30.602919  99.999001  0.000  ...   0.010266           0    NaN
# 1  119.401807  11.767414   8.597000  0.039  ...   0.010609           0    NaN
# 2   63.394122 -75.906397  11.074000  0.022  ...   0.013835           0    NaN
# 3  116.065371  -4.564768  10.905000  0.023  ...   0.016555           0    NaN
# 4  116.065371  -4.564768  10.905000  0.023  ...   0.012638           0    NaN
#
#    CU_FE_SPEC  CU_FE_ERR CU_FE_FLAG  CE_FE  CE_FE_SPEC  CE_FE_ERR  CE_FE_FLAG
# 0         NaN   0.059403          2    NaN         NaN        NaN          64
# 1         NaN   0.001221          2    NaN         NaN        NaN          64
# 2         NaN   0.102594          2    NaN         NaN        NaN          64
# 3         NaN   0.123839          2    NaN         NaN        NaN          64
# 4         NaN   0.107103          2    NaN         NaN        NaN          64
#
# [5 rows x 191 columns]

# %%
df.describe()
# Out:
#                   RA            DEC           GLON           GLAT  \
# count  733900.000000  733900.000000  733901.000000  733901.000000
# mean      179.031201       6.688964     161.564433       7.680005
# std        96.801018      39.649117     101.804392      35.064978
# min         0.000103     -87.224808       0.000088     -89.909116
# 25%        93.116921     -22.628102      74.885580     -15.130762
# 50%       181.898395      11.996523     160.183732       3.276527
# 75%       265.892360      39.576674     241.210803      32.805555
# max       359.999181      87.608246     359.999832      89.931476
#
#                    J          J_ERR              H          H_ERR  \
# count  723596.000000  722680.000000  733886.000000  722006.000000
# mean       11.543006       0.024710      10.840332       0.026333
# std         3.873045       0.029999       1.861256       0.042978
# min         5.180000       0.000000       0.358000       0.000000
# 25%        10.446000       0.022000       9.925000       0.022000
# 50%        11.445000       0.023000      10.889000       0.024000
# 75%        12.440000       0.026000      11.796000       0.028000
# max        99.999001       9.998000      99.999001       9.999000
#
#                    K          K_ERR  ...      NI_FE_ERR     NI_FE_FLAG  CU_FE  \
# count  723589.000000  721512.000000  ...  633827.000000  733901.000000    0.0
# mean       10.759167       0.023649  ...       0.018935       8.776377    NaN
# std         3.869474       0.076668  ...       0.010740      36.981835    NaN
# min         4.382000       0.000000  ...       0.005889       0.000000    NaN
# 25%         9.746000       0.019000  ...       0.012312       0.000000    NaN
# 50%        10.712000       0.021000  ...       0.016329       0.000000    NaN
# 75%        11.555000       0.024000  ...       0.022474       0.000000    NaN
# max        99.999001       9.998000  ...       1.736116     355.000000    NaN
#
#        CU_FE_SPEC      CU_FE_ERR     CU_FE_FLAG          CE_FE     CE_FE_SPEC  \
# count         0.0  442416.000000  733901.000000  353995.000000  353995.000000
# mean          NaN       0.103878      95.555146      -0.120582      -0.064922
# std           NaN       0.608181     125.064670       0.270995       0.270995
# min           NaN       0.000587       0.000000      -2.510510      -2.454850
# 25%           NaN       0.013521       2.000000      -0.228593      -0.172932
# 50%           NaN       0.054230       2.000000      -0.117369      -0.061709
# 75%           NaN       0.092658     259.000000       0.001460       0.057120
# max           NaN      60.004436     291.000000       2.913390       2.969050
#
#            CE_FE_ERR     CE_FE_FLAG
# count  353995.000000  733901.000000
# mean        0.103885      35.717042
# std         0.131483      48.138724
# min         0.027156       0.000000
# 25%         0.061052       0.000000
# 50%         0.083012       0.000000
# 75%         0.118397      64.000000
# max         3.046578     354.000000
#
# [8 rows x 169 columns]

# %%
display(df.columns)
# Out:
# Index(['APOGEE_ID', 'TELESCOPE', 'FIELD', 'ALT_ID', 'RA', 'DEC', 'GLON',
#        'GLAT', 'J', 'J_ERR',
#        ...
#        'NI_FE_ERR', 'NI_FE_FLAG', 'CU_FE', 'CU_FE_SPEC', 'CU_FE_ERR',
#        'CU_FE_FLAG', 'CE_FE', 'CE_FE_SPEC', 'CE_FE_ERR', 'CE_FE_FLAG'],
#       dtype='object', length=191)

# %%
df.dtypes
# Out:
# APOGEE_ID      object
# TELESCOPE      object
# FIELD          object
# ALT_ID         object
# RA            float64
#                ...
# CU_FE_FLAG      int64
# CE_FE         float64
# CE_FE_SPEC    float64
# CE_FE_ERR     float64
# CE_FE_FLAG      int64
# Length: 191, dtype: object

# %%
df = df4

# %%
# subset all chemical abundances (collumn name contain "_FE")
chemical_subset = df.filter(regex='_FE', axis=1) 

# merge with + df.filter(regex='_H', axis=1)
chemical_subset = pd.concat([chemical_subset, df.filter(regex='_H', axis=1)], axis=1)

# create a df without the chemical abundances
df_no_chemical = df.drop(chemical_subset.columns, axis=1)

# %%
df = df_no_chemical

# %%
missing_values = df.isnull().sum()

chemical_subset_missing_values = chemical_subset.isnull().sum()

# %%
missing_values = missing_values[missing_values > 0]    

missing_values.sort_values(ascending=False, inplace=True)

chemical_subset_missing_values = chemical_subset_missing_values[chemical_subset_missing_values > 0]

chemical_subset_missing_values.sort_values(ascending=False, inplace=True)

# %%
if len(missing_values) > 0:

    plt.figure(figsize=(15, 8))  
    missing_values.plot(kind='bar')

    plt.title('Nombre de valeurs nulles par colonne')
    plt.xlabel('Nom des colonnes')
    plt.ylabel('Nombre de valeurs nulles')
    plt.xticks( ha='right', fontsize=8)  
    


    plt.tight_layout()  # Assure que tout s'affiche bien dans la figure
    plt.show()

# %%
if len(chemical_subset_missing_values) > 0:

    plt.figure(figsize=(15, 8))  
    chemical_subset_missing_values.plot(kind='bar')

    plt.title('Nombre de valeurs nulles par colonne')
    plt.xlabel('Nom des colonnes')
    plt.ylabel('Nombre de valeurs nulles')
    plt.xticks( ha='right', fontsize=8)  


    plt.tight_layout()  # Assure que tout s'affiche bien dans la figure
    plt.show()

# %%
low_variability_columns = []

for col in df.columns:
    try:
        # Si la colonne contient moins de 5 valeurs uniques, on l'ajoute à la liste
        if df[col].nunique() < 5:
            low_variability_columns.append(col)
    except TypeError:
        print(f"error with column {col}")

print("Colonnes avec faible variabilité :", low_variability_columns)
# Out:
# error with column PARAMFLAG
# error with column X_M
# error with column X_M_ERR
# error with column ELEM_CHI2
# error with column ELEMFRAC
# error with column X_M_SPEC
# Colonnes avec faible variabilité : ['TELESCOPE', 'APOGEE2_TARGET4', 'RV_ALPHA', 'RV_CARB', 'MAX_JK']

# %%
# create an error dataset containing all errors 
chemical_errors_subset = chemical_subset.filter(regex='_ERR', axis=1)

# create an error dataset containing all specs
chemical_specs_subset = chemical_subset.filter(regex='_SPEC', axis=1)

# create a dataset containing all the flags
flags_subset = chemical_subset.filter(regex='FLAG', axis=1)

# remove flags, err and spec from the chemical_subset
chemical_subset = chemical_subset.drop(chemical_errors_subset.columns, axis=1)
chemical_subset = chemical_subset.drop(chemical_specs_subset.columns, axis=1)
chemical_subset = chemical_subset.drop(flags_subset.columns, axis=1)

# %%
flags_subset.hist(figsize=(15, 12), bins=30, edgecolor='black')
plt.tight_layout()
plt.show()

# %%
chemical_specs_subset.hist(figsize=(15, 12), bins=30, edgecolor='black')
plt.tight_layout()
plt.show()

# %%
chemical_errors_subset.hist(figsize=(15, 12), bins=30, edgecolor='black')
plt.tight_layout()
plt.show()

# %%
chemical_subset.hist(figsize=(15, 12), bins=30, edgecolor='black')
plt.tight_layout()
plt.show()

# %%
chemical_subset.describe()
# Out:
#               RV_FEH           C_FE          CI_FE           N_FE  \
# count  722905.000000  643860.000000  640781.000000  591028.000000
# mean       -0.481695      -0.019660      -0.026724       0.153415
# std         0.521245       0.136690       0.151087       0.235277
# min        -2.500000      -2.569600      -2.167200      -2.484940
# 25%        -0.655817      -0.068629      -0.096530       0.048654
# 50%        -0.387937      -0.007691      -0.019620       0.164520
# 75%        -0.140608       0.049114       0.050469       0.245960
# max         0.500000       1.529500       1.473540       2.791340
#
#                 O_FE          NA_FE          MG_FE          AL_FE  \
# count  643504.000000  567221.000000  646291.000000  572099.000000
# mean        0.113316      -0.037907       0.086484       0.084597
# std         0.147854       0.362338       0.134797       0.163549
# min        -1.998207      -2.827178      -1.709735      -2.566144
# 25%         0.024019      -0.114108       0.006522       0.017449
# 50%         0.085721       0.017664       0.063213       0.087211
# 75%         0.184313       0.128914       0.146786       0.171701
# max         2.039563       2.847242       1.872143       2.931121
#
#                SI_FE  P_FE  ...          CO_FE          NI_FE  CU_FE  \
# count  646151.000000   0.0  ...  388270.000000  633827.000000    0.0
# mean        0.066517   NaN  ...       0.033257       0.024392    NaN
# std         0.101628   NaN  ...       0.265784       0.092472    NaN
# min        -1.392327   NaN  ...      -2.981460      -2.930750    NaN
# 25%         0.007887   NaN  ...      -0.019135      -0.004694    NaN
# 50%         0.051817   NaN  ...       0.072580       0.029368    NaN
# 75%         0.111780   NaN  ...       0.141343       0.060413    NaN
# max         1.827411   NaN  ...       3.374180       2.982033    NaN
#
#                CE_FE          MIN_H          MAX_H  GAIAEDR3_R_HI_GEO  \
# count  353995.000000  733901.000000  733901.000000      720894.000000
# mean       -0.120582   -4090.077598    4101.802215        3131.868156
# std         0.270995    4921.212511    4911.449171        4831.919151
# min        -2.510510   -9999.990234      11.000000           3.221115
# 25%        -0.228593   -9999.990234      12.200000         392.799835
# 50%        -0.117369       7.000000      12.200000        1260.441284
# 75%         0.001460       7.000000    9999.990234        3954.993652
# max         2.913390      13.800000    9999.990234      144939.843750
#
#        GAIAEDR3_R_HI_PHOTOGEO            M_H           FE_H
# count           720010.000000  647025.000000  647042.000000
# mean              2967.507364      -0.232709      -0.231800
# std               4408.001546       0.381630       0.377003
# min                  3.220690      -2.468600      -2.468600
# 25%                391.723656      -0.401310      -0.402030
# 50%               1250.132996      -0.173630      -0.171510
# 75%               3884.044250       0.013517       0.014171
# max              73863.187500       0.968570       0.957890
#
# [8 rows x 28 columns]

# %%
chemical_subset
# Out:
#           RV_FEH      C_FE     CI_FE      N_FE      O_FE     NA_FE     MG_FE  \
# 0      -0.203651  0.004847  0.011280  0.124265  0.114938  0.146668  0.035147
# 1      -0.401404  0.009295 -0.006826  0.151220  0.083402  0.050112  0.030429
# 2      -0.436139  0.061738  0.070630 -0.111900  0.235343 -0.190826  0.165238
# 3      -0.702422  0.112730  0.124440  0.114560  0.045069 -0.179346  0.038494
# 4      -0.724421  0.032651  0.070725 -0.489060  0.140573 -1.166266 -0.001095
# ...          ...       ...       ...       ...       ...       ...       ...
# 733896 -0.135259       NaN       NaN       NaN       NaN       NaN       NaN
# 733897 -0.365796 -0.060314 -0.099930  0.201880  0.088913 -0.127408  0.083532
# 733898  0.001282 -0.011308 -0.070493  0.209650  0.050574  0.042082  0.064306
# 733899 -1.147642 -0.616490 -0.639930 -0.004530 -0.064257  0.043602 -0.211707
# 733900 -1.079865  0.210440  0.226260  1.476850  0.284273  0.055734  0.293968
#
#            AL_FE     SI_FE  P_FE  ...     NI_FE  CU_FE     CE_FE        MIN_H  \
# 0       0.075221  0.067189   NaN  ...  0.051278    NaN       NaN -9999.990234
# 1            NaN -0.028965   NaN  ...  0.007683    NaN       NaN     7.000000
# 2       0.296304  0.096593   NaN  ...  0.013930    NaN       NaN     7.000000
# 3       0.059596  0.138218   NaN  ... -0.108750    NaN       NaN -9999.990234
# 4       0.013086  0.130076   NaN  ... -0.069440    NaN       NaN     5.000000
# ...          ...       ...   ...  ...       ...    ...       ...          ...
# 733896       NaN       NaN   NaN  ...       NaN    NaN       NaN     7.000000
# 733897  0.135759  0.069318   NaN  ...  0.022203    NaN -0.058750     7.000000
# 733898  0.083671 -0.009388   NaN  ...  0.032992    NaN -0.103446     7.000000
# 733899 -0.528719 -0.177039   NaN  ... -0.103507    NaN  0.107710 -9999.990234
# 733900  0.161246  0.281833   NaN  ... -0.164540    NaN       NaN -9999.990234
#
#               MAX_H  GAIAEDR3_R_HI_GEO  GAIAEDR3_R_HI_PHOTOGEO  \
# 0       9999.990234                NaN                     NaN
# 1         12.200000        3464.556396             3507.732422
# 2         12.200000        3922.614014              970.810852
# 3       9999.990234         767.333374              766.532227
# 4         12.500000         767.333374              766.532227
# ...             ...                ...                     ...
# 733896    12.200000         690.270630              692.325989
# 733897    12.200000        2241.050537             2339.150635
# 733898    11.500000        2854.376221             2901.199219
# 733899  9999.990234       11551.600586            12214.619141
# 733900  9999.990234         490.179077              489.512360
#
#                                                       X_H       M_H      FE_H
# 0       [0.008309399709105492, 0.014742500148713589, 0...  0.005657  0.003463
# 1       [-0.15138529241085052, -0.16750599443912506, -... -0.147680 -0.160680
# 2       [-0.21379201114177704, -0.20490001142024994, -... -0.268750 -0.275530
# 3       [-0.14024001359939575, -0.12852999567985535, -... -0.245100 -0.252970
# 4       [-0.18151900172233582, -0.1434449851512909, -0... -0.221510 -0.214170
# ...                                                   ...       ...       ...
# 733896  [0.043449997901916504, -0.004979997873306274, ...       NaN       NaN
# 733897  [-0.2968739867210388, -0.3364900052547455, -0.... -0.229250 -0.236560
# 733898  [0.1035120040178299, 0.04432699829339981, 0.32...  0.119920  0.114820
# 733899  [-1.666990041732788, -1.6904300451278687, -1.0... -1.041800 -1.050500
# 733900  [-0.4388299882411957, -0.423009991645813, 0.82... -0.672220 -0.649270
#
# [733901 rows x 29 columns]

# %%
import seaborn as sns
sns.set(style="whitegrid")

plt.figure(figsize=(12, 6))
sns.boxplot(data=chemical_subset)
plt.xticks(rotation=90)
plt.title('Distribution des éléments chimiques')
plt.ylabel('Valeurs')
plt.xlabel('Éléments chimiques')
plt.show()

# Créer un histogramme pour chaque élément chimique
chemical_subset.hist(bins=20, figsize=(15, 10), layout=(4, 7))
plt.suptitle('Distribution des éléments chimiques')
plt.show()

# %%
# Calculer la somme des valeurs de chaque élément chimique
somme_elements = chemical_subset.sum()

# Convertir en DataFrame pour faciliter la visualisation
somme_df = pd.DataFrame(somme_elements, columns=['Somme'])

# Configuration des styles
sns.set(style="whitegrid")

# Créer un boxplot pour la somme des éléments chimiques
plt.figure(figsize=(10, 6))
sns.boxplot(y=somme_df['Somme'])
plt.title('Distribution de la somme des valeurs de chaque élément chimique')
plt.ylabel('Somme des valeurs')
plt.show()

# Créer un histogramme pour la somme des éléments chimiques
plt.figure(figsize=(10, 6))
sns.histplot(somme_df['Somme'], bins=20, kde=True)
plt.title('Distribution de la somme des valeurs de chaque élément chimique')
plt.xlabel('Somme des valeurs')
plt.ylabel('Fréquence')
plt.show()
